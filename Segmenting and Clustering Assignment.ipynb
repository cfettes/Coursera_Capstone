# %% [markdown]
# # Segmenting and Clustering Neighbourhoods in Toronto

# %% [markdown]
# For this assignment, you will be required to explore and cluster the neighborhoods in Toronto.
#
# Start by creating a new Notebook for this assignment.
#
# Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe

# %% [markdown]
# First, dependencies are downloaded

# %%
import requests
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim

import json
from IPython.display import Image
from IPython.core.display import HTML
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Libraries imported')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported

# %% [markdown]
# # Part 1
# Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe
#
# To create the above dataframe:
# + The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
# + Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
# + More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.
# + If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. So for the 9th cell in the table on the Wikipedia page, the value of the Borough and the Neighborhood columns will be Queen's Park.
# + Clean your Notebook and add Markdown cells to explain your work and any assumptions you are making.
# + In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %% [markdown]
# ### Create a dataframe with 3 columns: PostalCode, Borough and Neighborhood

# %%
#create dataframe with 3 columns containing information scraped from the Wikipedia page
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
r = requests.get(url)
html = r.text

bs = BeautifulSoup(html)
table=bs.find('tbody')
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])
df = pd.DataFrame(data,columns=['PostalCodes','Borough','Neighbourhood'])
df.head()
# Out:
#   PostalCodes           Borough     Neighbourhood
# 0         M1A      Not assigned      Not assigned
# 1         M2A      Not assigned      Not assigned
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Remove cells with a Borough that is labelled 'Not Assigned'

# %%
# remove cells with a borough that is Not Assigned
df['Borough'].replace('Not assigned', np.nan,inplace=True)
df.dropna(subset=['Borough'],inplace=True)
df.head()
# Out:
#   PostalCodes           Borough     Neighbourhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M5A  Downtown Toronto       Regent Park
# 6         M6A        North York  Lawrence Heights

# %% [markdown]
# ### Combine rows of neighborhoods with the same postal code

# %%
df2 = df.groupby(['PostalCodes','Borough'])['Neighbourhood'].apply(','.join).reset_index()
df2.columns = ['PostalCodes','Borough','Neighbourhood']
df2.head()
# Out:
#   PostalCodes      Borough                         Neighbourhood
# 0         M1B  Scarborough                         Rouge,Malvern
# 1         M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill
# 3         M1G  Scarborough                                Woburn
# 4         M1H  Scarborough                             Cedarbrae

# %% [markdown]
# ### Postal codes with a borough but a not assigned neighborhood, change neighborhood to the same as borough

# %%
for index, row in df2.iterrows():
    if row['Neighbourhood']=='Not assigned':
        row['Neighbourhood'] = row['Borough']
df.head()
# Out:
#   PostalCodes           Borough     Neighbourhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M5A  Downtown Toronto       Regent Park
# 6         M6A        North York  Lawrence Heights

# %% [markdown]
# ### Use the .shape method to print number of rows of the dataframe

# %%
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2

# %% [markdown]
# Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.
#
# In an older version of this course, we were leveraging the Google Maps Geocoding API to get the latitude and the longitude coordinates of each neighborhood. However, recently Google started charging for their API: http://geoawesomeness.com/developers-up-in-arms-over-google-maps-api-insane-price-hike/, so we will use the Geocoder Python package instead: https://geocoder.readthedocs.io/index.html.
#
# The problem with this Package is you have to be persistent sometimes in order to get the geographical coordinates of a given postal code. So you can make a call to get the latitude and longitude coordinates of a given postal code and the result would be None, and then make the call again and you would get the coordinates. So, in order to make sure that you get the coordinates for all of our neighborhoods, you can run a while loop for each postal code.
#
# Given that this package can be very unreliable, in case you are not able to get the geographical coordinates of the neighborhoods using the Geocoder package, here is a link to a csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data

# %% [markdown]
# Despite multiple attempts, geocoder ran for hours and never completed, so the decision was made to utilise the csv file instead

# %%
import io
url2 = 'http://cocl.us/Geospatial_data'
g = requests.get(url2).content
s = pd.read_csv(io.StringIO(g.decode('utf-8')))
s.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
s.rename(columns={'Postal Code':'PostalCodes'},inplace=True)
s.sort_values(by = ['PostalCodes'],ascending=True)
s.head()
# Out:
#   PostalCodes   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df2.sort_values(by=['PostalCodes'],ascending=True)
df2.head()
# Out:
#   PostalCodes      Borough                         Neighbourhood
# 0         M1B  Scarborough                         Rouge,Malvern
# 1         M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2         M1E  Scarborough       Guildwood,Morningside,West Hill
# 3         M1G  Scarborough                                Woburn
# 4         M1H  Scarborough                             Cedarbrae

# %%
df2 = pd.merge(df2,s,on='PostalCodes')
df2
# Out:
#     PostalCodes           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# ..          ...               ...
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A      Queen's Park
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# # Part 3

# %% [markdown]
# Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data. It is up to you.
#
# Just make sure:
# + to add enough Markdown cells to explain what you decided to do and to report any observations you make.
# + to generate maps to visualize your neighborhoods and how they cluster together.

# %%
from geopy.geocoders import Nominatim
import json 
from pandas.io.json import json_normalize
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

#Foursquare credentials
CLIENT_ID = 'T1NIO3TDFZS402OHWBDJBFIRAY2Q0LZK1P3AM5HY1UOHXYUQ'
CLIENT_SECRET = 'HV2DQUDBZJXARPLC5RLWTZUXT1LJ52LK0FGBIBWIFRBNA11B'
VERSION = 20180605
LIMIT = 100 # to limit number of venues returned
radius = 500 #defines radius of search

# %% [markdown]
# ### Functions defined

# %%
#function to extract the venue category
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#function to repear the same process to all neighborhoods
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
        #create API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID,
            CLIENT_SECRET,
            VERSION,
            lat,
            lng,
            radius,
            LIMIT)
        #make GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        #return only relevant info for each nearby venue
        venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])
    
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood',
                            'Neighbourhood Latitude',
                            'Neighbourhood Longitude',
                            'Venue',
                            'Venue Latitude',
                            'Venue Longitude',
                            'Venue Category']
    return(nearby_venues)

# %%
#function to sort venues in descending order
def return_most_common_venues(row,num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ### Explore neighbourhoods in Toronto

# %%
#explore venues in all neighbourhoods and create venue dataframe
toronto_venues = getNearbyVenues(names=df2['PostalCodes'], latitudes=df2['Latitude'],longitudes=df2['Longitude'])
print(toronto_venues.shape)
# Out:
# (2231, 7)

# %%
#find how many venues were returned for each neighbourhood
toronto_venues.groupby('Neighbourhood').count()
print('There are {} unique categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 274 unique categories.

# %%
toronto_venues.head()
# Out:
#   Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0           M1B               43.806686               -79.194353
# 1           M1C               43.784535               -79.160497
# 2           M1C               43.784535               -79.160497
# 3           M1E               43.763573               -79.188711
# 4           M1E               43.763573               -79.188711
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0                          Wendy's       43.807448       -79.199056
# 1            Royal Canadian Legion       43.782533       -79.163085
# 2        Affordable Toronto Movers       43.787919       -79.162977
# 3  Swiss Chalet Rotisserie & Grill       43.767697       -79.189914
# 4                G & G Electronics       43.765309       -79.191537
#
#          Venue Category
# 0  Fast Food Restaurant
# 1                   Bar
# 2         Moving Target
# 3           Pizza Place
# 4     Electronics Store

# %% [markdown]
# ### Analyse neighbourhoods in Toronto

# %%
#one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']],prefix="",prefix_sep="")

#add neighbourhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood']

#move neighbourhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]]+list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_onehot.head()
toronto_onehot.shape
# Out:
# (2231, 275)

# %%
#group rows by neighbourhoodand by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped.head()
toronto_grouped.shape
# Out:
# (100, 275)

# %%
#create a dataframe of the 5 most common venues in each neighbourhood
num_top_venues = 10
indicators = ['st','nd','rd']
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1,indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

#create dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind,1:] = return_most_common_venues(
        toronto_grouped.iloc[ind, :], num_top_venues)
print(neighbourhoods_venues_sorted.shape)
neighbourhoods_venues_sorted
# Out:
# (100, 11)
#    Neighbourhood       1st Most Common Venue          2nd Most Common Venue  \
# 0            M1B        Fast Food Restaurant                    Yoga Studio
# 1            M1C               Moving Target                            Bar
# 2            M1E              Breakfast Spot            Rental Car Location
# 3            M1G                 Coffee Shop                       Pharmacy
# 4            M1H            Hakka Restaurant                Thai Restaurant
# 5            M1J                  Playground              Convenience Store
# 6            M1K            Department Store                     Hobby Shop
# 7            M1L                    Bus Line           Fast Food Restaurant
# 8            M1M         American Restaurant                          Motel
# 9            M1N             College Stadium                           Café
# 10           M1P           Indian Restaurant                      Pet Store
# 11           M1R              Breakfast Spot                         Bakery
# 12           M1S              Breakfast Spot                         Lounge
# 13           M1T                 Pizza Place           Fast Food Restaurant
# 14           M1V                        Park                     Playground
# 15           M1W        Fast Food Restaurant             Chinese Restaurant
# 16           M2H        Fast Food Restaurant                        Dog Run
# 17           M2J              Clothing Store           Fast Food Restaurant
# 18           M2K         Japanese Restaurant                           Bank
# 19           M2L                   Cafeteria                    Yoga Studio
# 20           M2N                 Coffee Shop               Ramen Restaurant
# 21           M2P                        Park                           Bank
# 22           M2R                    Pharmacy                 Discount Store
# 23           M3A        Fast Food Restaurant                           Park
# 24           M3B        Gym / Fitness Center           Caribbean Restaurant
# 25           M3C                         Gym               Asian Restaurant
# 26           M3H                 Coffee Shop                  Deli / Bodega
# 27           M3J          Falafel Restaurant                 Massage Studio
# 28           M3K                        Park                        Airport
# 29           M3L               Grocery Store                           Park
# 30           M3M                  Food Truck                 Baseball Field
# 31           M3N              Discount Store           Gym / Fitness Center
# 32           M4A                Intersection                    Coffee Shop
# 33           M4B        Fast Food Restaurant                    Pizza Place
# 34           M4C                  Beer Store                    Curling Ice
# 35           M4E        Other Great Outdoors              Health Food Store
# 36           M4G                 Coffee Shop            Sporting Goods Shop
# 37           M4H           Indian Restaurant                   Burger Joint
# 38           M4J                        Park                    Pizza Place
# 39           M4K            Greek Restaurant                    Coffee Shop
# 40           M4L                        Park                 Ice Cream Shop
# 41           M4M                        Café                    Coffee Shop
# 42           M4N                        Park             Photography Studio
# 43           M4P        Gym / Fitness Center                           Park
# 44           M4R                 Coffee Shop                 Clothing Store
# 45           M4S                 Pizza Place                 Sandwich Place
# 46           M4T                       Trail                     Playground
# 47           M4V                 Coffee Shop                            Pub
# 48           M4W                        Park                     Playground
# 49           M4X                 Coffee Shop                     Restaurant
# 50           M4Y                 Coffee Shop            Japanese Restaurant
# 51           M5A                 Coffee Shop                           Park
# 52           M5B                 Coffee Shop                 Clothing Store
# 53           M5C                 Coffee Shop                          Hotel
# 54           M5E                 Coffee Shop                   Cocktail Bar
# 55           M5G                 Coffee Shop                           Café
# 56           M5H                 Coffee Shop                           Café
# 57           M5J                 Coffee Shop                          Hotel
# 58           M5K                 Coffee Shop                           Café
# 59           M5L                 Coffee Shop                           Café
# 60           M5M                 Coffee Shop             Italian Restaurant
# 61           M5N                      Garden                    Music Venue
# 62           M5P                       Trail                           Park
# 63           M5R                 Coffee Shop                           Café
# 64           M5S                        Café                     Restaurant
# 65           M5T                        Café  Vegetarian / Vegan Restaurant
# 66           M5V             Airport Service               Airport Terminal
# 67           M5W                 Coffee Shop                           Café
# 68           M5X                 Coffee Shop                           Café
# 69           M6A      Furniture / Home Store                 Clothing Store
# 70           M6B                        Park            Japanese Restaurant
# 71           M6C                       Trail                          Field
# 72           M6E                        Park                  Women's Store
# 73           M6G               Grocery Store                           Café
# 74           M6H                    Pharmacy                         Bakery
# 75           M6J                         Bar                    Coffee Shop
# 76           M6K              Breakfast Spot                           Café
# 77           M6L                        Park                         Bakery
# 78           M6M              Sandwich Place                     Restaurant
# 79           M6N                    Bus Line           Caribbean Restaurant
# 80           M6P          Mexican Restaurant                            Bar
# 81           M6R              Breakfast Spot                      Gift Shop
# 82           M6S                 Coffee Shop                           Café
# 83           M7A                 Coffee Shop                          Diner
# 84           M7R                 Coffee Shop                          Hotel
# 85           M7Y        Gym / Fitness Center                         Garden
# 86           M8V                      Bakery            American Restaurant
# 87           M8W                 Pizza Place                            Gym
# 88           M8X                        Park                          River
# 89           M8Y                   Locksmith                 Baseball Field
# 90           M8Z              Hardware Store                  Tanning Salon
# 91           M9B                        Bank                    Golf Course
# 92           M9C                   Pet Store                    Pizza Place
# 93           M9L         Empanada Restaurant                   Home Service
# 94           M9M  Construction & Landscaping                 Baseball Field
# 95           M9N                        Park                    Yoga Studio
# 96           M9P                 Pizza Place                   Intersection
# 97           M9R                        Park                    Pizza Place
# 98           M9V               Grocery Store           Fast Food Restaurant
# 99           M9W                         Bar            Rental Car Location
#
#           3rd Most Common Venue        4th Most Common Venue  \
# 0   Eastern European Restaurant                     Dive Bar
# 1                   Yoga Studio                        Diner
# 2                   Pizza Place            Electronics Store
# 3             Korean Restaurant                  Yoga Studio
# 4           Fried Chicken Joint                         Bank
# 5                   Yoga Studio          Dumpling Restaurant
# 6                   Coffee Shop           Chinese Restaurant
# 7                  Intersection                Metro Station
# 8                Farmers Market           Falafel Restaurant
# 9                  Skating Rink        General Entertainment
# 10        Vietnamese Restaurant    Latin American Restaurant
# 11                   Smoke Shop    Middle Eastern Restaurant
# 12                 Skating Rink               Clothing Store
# 13                 Noodle House          Fried Chicken Joint
# 14          Dumpling Restaurant               Discount Store
# 15               Breakfast Spot            Indian Restaurant
# 16     Mediterranean Restaurant                  Golf Course
# 17                  Coffee Shop                     Tea Room
# 18                         Café           Chinese Restaurant
# 19          Dumpling Restaurant                     Dive Bar
# 20                         Café                  Pizza Place
# 21            Convenience Store                  Flower Shop
# 22                Grocery Store                  Pizza Place
# 23            Food & Drink Shop          Dumpling Restaurant
# 24                         Café               Baseball Field
# 25                   Beer Store                  Coffee Shop
# 26                  Pizza Place                   Restaurant
# 27         Caribbean Restaurant                          Bar
# 28                     Bus Stop          Dumpling Restaurant
# 29                         Bank                Shopping Mall
# 30                 Home Service                  Yoga Studio
# 31                Grocery Store           Athletics & Sports
# 32                 Hockey Arena        Portuguese Restaurant
# 33                    Pet Store           Athletics & Sports
# 34                         Park                     Pharmacy
# 35                          Pub                 Neighborhood
# 36                 Burger Joint       Furniture / Home Store
# 37                  Yoga Studio                         Bank
# 38                  Coffee Shop            Convenience Store
# 39               Ice Cream Shop           Italian Restaurant
# 40                    Pet Store                  Pizza Place
# 41                    Gastropub           Italian Restaurant
# 42                  Swim School                     Bus Line
# 43               Sandwich Place            Food & Drink Shop
# 44          Sporting Goods Shop                  Yoga Studio
# 45                 Dessert Shop                  Coffee Shop
# 46                  Summer Camp                  Yoga Studio
# 47          American Restaurant                   Restaurant
# 48                     Building                        Trail
# 49                  Pizza Place                          Pub
# 50             Sushi Restaurant                      Gay Bar
# 51                       Bakery                         Café
# 52               Cosmetics Shop    Middle Eastern Restaurant
# 53           Italian Restaurant                         Café
# 54                         Café                  Cheese Shop
# 55           Italian Restaurant               Ice Cream Shop
# 56                          Bar              Thai Restaurant
# 57                     Aquarium           Italian Restaurant
# 58                        Hotel                   Restaurant
# 59                        Hotel          American Restaurant
# 60             Sushi Restaurant             Greek Restaurant
# 61                 Home Service                    Drugstore
# 62             Sushi Restaurant                Jewelry Store
# 63               Sandwich Place                  Pizza Place
# 64                    Bookstore          Japanese Restaurant
# 65           Chinese Restaurant                          Bar
# 66               Airport Lounge                Boat or Ferry
# 67                   Restaurant                     Beer Bar
# 68                   Steakhouse                        Hotel
# 69            Accessories Store          Arts & Crafts Store
# 70             Sushi Restaurant                  Pizza Place
# 71                      Dog Run                 Hockey Arena
# 72                       Market         Fast Food Restaurant
# 73                         Park                  Coffee Shop
# 74                  Supermarket               Discount Store
# 75             Asian Restaurant                  Pizza Place
# 76                  Coffee Shop                  Yoga Studio
# 77   Construction & Landscaping             Basketball Court
# 78            Convenience Store        Check Cashing Service
# 79                  Pizza Place            Convenience Store
# 80                         Café                    Gastropub
# 81  Eastern European Restaurant                 Dessert Shop
# 82                  Pizza Place           Italian Restaurant
# 83                          Gym                         Park
# 84         Gym / Fitness Center          Fried Chicken Joint
# 85                   Comic Shop                         Park
# 86                         Café          Fried Chicken Joint
# 87               Sandwich Place                 Dance Studio
# 88                    Drugstore               Discount Store
# 89             Business Service                         Pool
# 90                Grocery Store         Fast Food Restaurant
# 91                  Yoga Studio          Dumpling Restaurant
# 92                   Beer Store                  Coffee Shop
# 93                  Yoga Studio          Dumpling Restaurant
# 94                  Yoga Studio  Eastern European Restaurant
# 95  Eastern European Restaurant                     Dive Bar
# 96               Sandwich Place                  Coffee Shop
# 97            Mobile Phone Shop                    Drugstore
# 98                  Pizza Place               Sandwich Place
# 99                    Drugstore                  Yoga Studio
#
#           5th Most Common Venue        6th Most Common Venue  \
# 0                       Dog Run             Doner Restaurant
# 1                      Dive Bar                      Dog Run
# 2                Medical Center                 Intersection
# 3           Dumpling Restaurant                     Dive Bar
# 4                        Bakery         Caribbean Restaurant
# 5                Discount Store                     Dive Bar
# 6                   Yoga Studio          Dumpling Restaurant
# 7                   Bus Station                 Soccer Field
# 8                   Event Space         Ethiopian Restaurant
# 9                    Donut Shop               Discount Store
# 10           Chinese Restaurant                    Drugstore
# 11  Eastern European Restaurant             Doner Restaurant
# 12  Eastern European Restaurant                      Dog Run
# 13              Thai Restaurant           Chinese Restaurant
# 14                     Dive Bar                      Dog Run
# 15                Grocery Store              Bubble Tea Shop
# 16                         Pool                  Yoga Studio
# 17             Toy / Game Store          Japanese Restaurant
# 18                     Dive Bar                      Dog Run
# 19                      Dog Run             Doner Restaurant
# 20                   Restaurant               Sandwich Place
# 21                  Yoga Studio          Dumpling Restaurant
# 22                  Coffee Shop                  Yoga Studio
# 23               Discount Store                     Dive Bar
# 24             Basketball Court          Japanese Restaurant
# 25         Fast Food Restaurant               Sandwich Place
# 26             Sushi Restaurant                         Bank
# 27                  Coffee Shop                  Yoga Studio
# 28                     Dive Bar                      Dog Run
# 29                        Hotel                   Donut Shop
# 30                      Dog Run             Doner Restaurant
# 31                 Liquor Store          Dumpling Restaurant
# 32          Dumpling Restaurant               Discount Store
# 33                    Gastropub                 Intersection
# 34                  Video Store                 Skating Rink
# 35                        Trail          Empanada Restaurant
# 36             Sushi Restaurant                Shopping Mall
# 37                 Liquor Store                         Park
# 38          Dumpling Restaurant               Discount Store
# 39       Furniture / Home Store                    Bookstore
# 40                Movie Theater                          Pub
# 41                       Bakery          American Restaurant
# 42                    Drugstore                     Dive Bar
# 43             Asian Restaurant                        Hotel
# 44                   Bagel Shop                    Gift Shop
# 45           Italian Restaurant                         Café
# 46               Discount Store                     Dive Bar
# 47                   Bagel Shop          Fried Chicken Joint
# 48          Dumpling Restaurant               Discount Store
# 49           Italian Restaurant                  Flower Shop
# 50                   Restaurant                  Men's Store
# 51           Mexican Restaurant                          Pub
# 52                         Café               Ice Cream Shop
# 53                   Restaurant                 Cocktail Bar
# 54                       Bakery                     Beer Bar
# 55               Sandwich Place                 Burger Joint
# 56                   Steakhouse               Breakfast Spot
# 57                         Café               Scenic Lookout
# 58           Italian Restaurant                    Gastropub
# 59                   Restaurant                    Gastropub
# 60               Ice Cream Shop                     Pharmacy
# 61               Discount Store                     Dive Bar
# 62                  Yoga Studio                     Dive Bar
# 63                         Park                    BBQ Joint
# 64                          Bar                       Bakery
# 65           Mexican Restaurant                  Coffee Shop
# 66                     Boutique             Sculpture Garden
# 67                        Hotel         Fast Food Restaurant
# 68                   Restaurant                Deli / Bodega
# 69             Fraternity House                  Event Space
# 70                          Pub                  Yoga Studio
# 71                  Yoga Studio                     Dive Bar
# 72           Falafel Restaurant                  Event Space
# 73                   Restaurant                   Baby Store
# 74                          Bar                         Park
# 75                 Cocktail Bar        Vietnamese Restaurant
# 76                          Bar                Burrito Place
# 77          Dumpling Restaurant                      Dog Run
# 78                  Yoga Studio                    Drugstore
# 79                  Yoga Studio                     Dive Bar
# 80          Arts & Crafts Store                        Diner
# 81                          Bar                         Bank
# 82             Sushi Restaurant                Smoothie Shop
# 83                Burrito Place           Italian Restaurant
# 84               Sandwich Place                Burrito Place
# 85                  Pizza Place                   Restaurant
# 86               Sandwich Place           Seafood Restaurant
# 87                     Pharmacy                  Coffee Shop
# 88                     Dive Bar                      Dog Run
# 89                  Yoga Studio  Eastern European Restaurant
# 90               Discount Store            Convenience Store
# 91                     Dive Bar                      Dog Run
# 92            Convenience Store                         Café
# 93                     Dive Bar                      Dog Run
# 94                      Dog Run             Doner Restaurant
# 95                      Dog Run             Doner Restaurant
# 96           Chinese Restaurant                   Donut Shop
# 97               Discount Store                     Dive Bar
# 98                   Beer Store                  Coffee Shop
# 99                        Diner                     Dive Bar
#
#        7th Most Common Venue        8th Most Common Venue  \
# 0                 Donut Shop                    Drugstore
# 1           Doner Restaurant                   Donut Shop
# 2         Mexican Restaurant                   Donut Shop
# 3                    Dog Run             Doner Restaurant
# 4         Athletics & Sports                       Lounge
# 5                    Dog Run             Doner Restaurant
# 6                    Dog Run             Doner Restaurant
# 7                     Bakery                         Park
# 8        Empanada Restaurant            Electronics Store
# 9                   Dive Bar                      Dog Run
# 10                  Dive Bar                      Dog Run
# 11                Donut Shop                    Drugstore
# 12          Doner Restaurant                   Donut Shop
# 13                      Bank           Italian Restaurant
# 14          Doner Restaurant                   Donut Shop
# 15                  Pharmacy               Cosmetics Shop
# 16       Dumpling Restaurant                     Dive Bar
# 17                    Bakery                   Food Court
# 18          Doner Restaurant                   Donut Shop
# 19                Donut Shop                    Drugstore
# 20         Electronics Store                    Juice Bar
# 21                   Dog Run             Doner Restaurant
# 22                 Drugstore                     Dive Bar
# 23                   Dog Run             Doner Restaurant
# 24               Yoga Studio                    Drugstore
# 25       Sporting Goods Shop                    Bike Shop
# 26               Bridal Shop                        Diner
# 27                 Drugstore                      Dog Run
# 28          Doner Restaurant                   Donut Shop
# 29            Discount Store                     Dive Bar
# 30                Donut Shop                    Drugstore
# 31                  Dive Bar                      Dog Run
# 32                  Dive Bar                      Dog Run
# 33                  Pharmacy                         Café
# 34                  Bus Stop               Cosmetics Shop
# 35         Electronics Store  Eastern European Restaurant
# 36                Sports Bar                   Beer Store
# 37                  Pharmacy                  Coffee Shop
# 38                  Dive Bar                      Dog Run
# 39                   Brewery              Bubble Tea Shop
# 40            Sandwich Place                Burrito Place
# 41               Yoga Studio            Convenience Store
# 42                   Dog Run             Doner Restaurant
# 43            Clothing Store               Breakfast Spot
# 44             Metro Station           Mexican Restaurant
# 45          Sushi Restaurant                         Park
# 46                   Dog Run             Doner Restaurant
# 47                Sports Bar                  Supermarket
# 48                  Dive Bar                      Dog Run
# 49                    Bakery                         Café
# 50  Mediterranean Restaurant                          Gym
# 51            Breakfast Spot            Electronics Store
# 52                   Theater         Fast Food Restaurant
# 53                  Beer Bar               Cosmetics Shop
# 54        Seafood Restaurant                   Steakhouse
# 55         Indian Restaurant                          Bar
# 56          Asian Restaurant          American Restaurant
# 57               Pizza Place                       Bakery
# 58                       Bar                       Bakery
# 59             Deli / Bodega                   Steakhouse
# 60               Pizza Place                          Pub
# 61                   Dog Run             Doner Restaurant
# 62                   Dog Run             Doner Restaurant
# 63            Cosmetics Shop                     Pharmacy
# 64     College Arts Building            French Restaurant
# 65       Dumpling Restaurant                       Bakery
# 66                       Bar              Harbor / Marina
# 67        Seafood Restaurant                 Cocktail Bar
# 68                       Gym          American Restaurant
# 69        Miscellaneous Shop                  Coffee Shop
# 70          Doner Restaurant               Discount Store
# 71          Doner Restaurant                   Donut Shop
# 72      Ethiopian Restaurant          Empanada Restaurant
# 73        Athletics & Sports           Italian Restaurant
# 74                      Bank         Gym / Fitness Center
# 75         French Restaurant                  Men's Store
# 76                Restaurant         Caribbean Restaurant
# 77          Doner Restaurant                   Donut Shop
# 78                  Dive Bar                      Dog Run
# 79                   Dog Run             Doner Restaurant
# 80       Fried Chicken Joint                       Bakery
# 81        Italian Restaurant                   Restaurant
# 82                Restaurant                    Bookstore
# 83       Japanese Restaurant                          Spa
# 84  Mediterranean Restaurant          American Restaurant
# 85             Burrito Place                   Skate Park
# 86                Restaurant                  Pizza Place
# 87              Skating Rink                          Pub
# 88          Doner Restaurant                   Donut Shop
# 89          Doner Restaurant                   Donut Shop
# 90            Sandwich Place                Burrito Place
# 91          Doner Restaurant                   Donut Shop
# 92              Liquor Store                     Pharmacy
# 93          Doner Restaurant                   Donut Shop
# 94                Donut Shop                    Drugstore
# 95                Donut Shop                    Drugstore
# 96            Discount Store                     Dive Bar
# 97                   Dog Run             Doner Restaurant
# 98       Fried Chicken Joint                     Pharmacy
# 99                   Dog Run             Doner Restaurant
#
#           9th Most Common Venue       10th Most Common Venue
# 0           Dumpling Restaurant            Electronics Store
# 1                     Drugstore          Dumpling Restaurant
# 2                Discount Store                     Dive Bar
# 3                    Donut Shop                    Drugstore
# 4                  Cupcake Shop                  Curling Ice
# 5                    Donut Shop                    Drugstore
# 6                    Donut Shop                    Drugstore
# 7                     Gift Shop            German Restaurant
# 8   Eastern European Restaurant                        Diner
# 9              Doner Restaurant                    Drugstore
# 10             Doner Restaurant                   Donut Shop
# 11          Dumpling Restaurant            Electronics Store
# 12                    Drugstore          Dumpling Restaurant
# 13                     Pharmacy  Eastern European Restaurant
# 14                    Drugstore  Eastern European Restaurant
# 15                  Pizza Place               Sandwich Place
# 16             Doner Restaurant                   Donut Shop
# 17            Convenience Store                   Restaurant
# 18                    Drugstore                  Yoga Studio
# 19  Eastern European Restaurant                        Field
# 20         Fast Food Restaurant          Japanese Restaurant
# 21                   Donut Shop                    Drugstore
# 22                      Dog Run             Doner Restaurant
# 23                   Donut Shop                    Drugstore
# 24             Doner Restaurant                   Donut Shop
# 25               Discount Store                   Restaurant
# 26          Fried Chicken Joint           Frozen Yogurt Shop
# 27             Doner Restaurant                   Donut Shop
# 28                    Drugstore  Eastern European Restaurant
# 29                      Dog Run             Doner Restaurant
# 30          Dumpling Restaurant  Eastern European Restaurant
# 31             Doner Restaurant                   Donut Shop
# 32             Doner Restaurant                   Donut Shop
# 33                         Bank         Gym / Fitness Center
# 34           Athletics & Sports                 Dance Studio
# 35          Dumpling Restaurant                    Drugstore
# 36                    Bike Shop            Fish & Chips Shop
# 37                  Pizza Place               Sandwich Place
# 38             Doner Restaurant                   Donut Shop
# 39                   Restaurant         Caribbean Restaurant
# 40                 Burger Joint                      Brewery
# 41                      Brewery           Seafood Restaurant
# 42                   Donut Shop          Dumpling Restaurant
# 43                Grocery Store                          Gym
# 44                        Diner                 Dessert Shop
# 45           Seafood Restaurant                   Restaurant
# 46                   Donut Shop                    Drugstore
# 47                  Pizza Place             Sushi Restaurant
# 48             Doner Restaurant                   Donut Shop
# 49                       Market               Breakfast Spot
# 50                    Gastropub                        Hotel
# 51        Performing Arts Venue                          Spa
# 52                   Restaurant                        Diner
# 53               Clothing Store               Breakfast Spot
# 54               Farmers Market  Eastern European Restaurant
# 55              Bubble Tea Shop                       Bakery
# 56                          Gym                        Hotel
# 57          Sporting Goods Shop                      Brewery
# 58                Deli / Bodega          American Restaurant
# 59                       Bakery                          Gym
# 60                   Restaurant                         Café
# 61                   Donut Shop          Dumpling Restaurant
# 62                   Donut Shop                    Drugstore
# 63                          Pub                 Burger Joint
# 64               Sandwich Place                   Beer Store
# 65        Vietnamese Restaurant                  Gaming Cafe
# 66                 Airport Gate           Airport Food Court
# 67          Japanese Restaurant               Farmers Market
# 68             Asian Restaurant                          Bar
# 69                     Boutique                Women's Store
# 70                     Dive Bar                      Dog Run
# 71                    Drugstore          Dumpling Restaurant
# 72            Electronics Store                        Diner
# 73                        Diner                    Nightclub
# 74                      Brewery    Middle Eastern Restaurant
# 75                         Café                   Restaurant
# 76                 Climbing Gym                    Pet Store
# 77                    Drugstore  Eastern European Restaurant
# 78             Doner Restaurant                   Donut Shop
# 79                   Donut Shop                    Drugstore
# 80    Cajun / Creole Restaurant       Furniture / Home Store
# 81                Movie Theater                      Dog Run
# 82    Latin American Restaurant            Fish & Chips Shop
# 83         Fast Food Restaurant           Seafood Restaurant
# 84    Middle Eastern Restaurant                    Drugstore
# 85                   Smoke Shop                      Brewery
# 86         Fast Food Restaurant                 Liquor Store
# 87             Doner Restaurant               Discount Store
# 88          Dumpling Restaurant           Dim Sum Restaurant
# 89                    Drugstore          Dumpling Restaurant
# 90                 Burger Joint                  Social Club
# 91                    Drugstore  Eastern European Restaurant
# 92          Empanada Restaurant         Ethiopian Restaurant
# 93                    Drugstore            Electronics Store
# 94          Dumpling Restaurant            Electronics Store
# 95          Dumpling Restaurant            Electronics Store
# 96                      Dog Run             Doner Restaurant
# 97                   Donut Shop          Dumpling Restaurant
# 98            Electronics Store          Empanada Restaurant
# 99                   Donut Shop          Dumpling Restaurant

# %% [markdown]
# ### Cluster Neighbourhoods by running k-means

# %%
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood',1)
kmeans = KMeans(n_clusters=kclusters,random_state=0).fit(toronto_grouped_clustering)
#check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 4, 0, 0, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
#create a new dataframe that includes the cluster as well as the top 10 venues for each neighbourhood
#add clustering labels
toronto_merged = df2
neighbourhoods_venues_sorted.rename(columns={'Neighbourhood':'Neighborhood'},inplace=True)
toronto_merged.rename(columns={'PostalCodes':'Neighborhood'}, inplace=True)

#add clustering labels
neighbourhoods_venues_sorted.insert(0,"Cluster labels",kmeans.labels_)

#merge toronto_grouped with df2 to add latitude and longitude for each neighbourhood
toronto_merged = toronto_merged.join(neighbourhoods_venues_sorted.set_index('Neighborhood'),on='Neighborhood')

toronto_merged.head()
# Out:
#   Neighborhood      Borough                         Neighbourhood   Latitude  \
# 0          M1B  Scarborough                         Rouge,Malvern  43.806686
# 1          M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2          M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3          M1G  Scarborough                                Woburn  43.770992
# 4          M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude  Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353             2.0  Fast Food Restaurant           Yoga Studio
# 1 -79.160497             4.0         Moving Target                   Bar
# 2 -79.188711             0.0        Breakfast Spot   Rental Car Location
# 3 -79.216917             0.0           Coffee Shop              Pharmacy
# 4 -79.239476             0.0      Hakka Restaurant       Thai Restaurant
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Eastern European Restaurant              Dive Bar               Dog Run
# 1                  Yoga Studio                 Diner              Dive Bar
# 2                  Pizza Place     Electronics Store        Medical Center
# 3            Korean Restaurant           Yoga Studio   Dumpling Restaurant
# 4          Fried Chicken Joint                  Bank                Bakery
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Doner Restaurant            Donut Shop             Drugstore
# 1               Dog Run      Doner Restaurant            Donut Shop
# 2          Intersection    Mexican Restaurant            Donut Shop
# 3              Dive Bar               Dog Run      Doner Restaurant
# 4  Caribbean Restaurant    Athletics & Sports                Lounge
#
#   9th Most Common Venue 10th Most Common Venue
# 0   Dumpling Restaurant      Electronics Store
# 1             Drugstore    Dumpling Restaurant
# 2        Discount Store               Dive Bar
# 3            Donut Shop              Drugstore
# 4          Cupcake Shop            Curling Ice

# %%
toronto_merged
# Out:
#     Neighborhood           Borough  \
# 0            M1B       Scarborough
# 1            M1C       Scarborough
# 2            M1E       Scarborough
# 3            M1G       Scarborough
# 4            M1H       Scarborough
# 5            M1J       Scarborough
# 6            M1K       Scarborough
# 7            M1L       Scarborough
# 8            M1M       Scarborough
# 9            M1N       Scarborough
# 10           M1P       Scarborough
# 11           M1R       Scarborough
# 12           M1S       Scarborough
# 13           M1T       Scarborough
# 14           M1V       Scarborough
# 15           M1W       Scarborough
# 16           M1X       Scarborough
# 17           M2H        North York
# 18           M2J        North York
# 19           M2K        North York
# 20           M2L        North York
# 21           M2M        North York
# 22           M2N        North York
# 23           M2P        North York
# 24           M2R        North York
# 25           M3A        North York
# 26           M3B        North York
# 27           M3C        North York
# 28           M3H        North York
# 29           M3J        North York
# 30           M3K        North York
# 31           M3L        North York
# 32           M3M        North York
# 33           M3N        North York
# 34           M4A        North York
# 35           M4B         East York
# 36           M4C         East York
# 37           M4E      East Toronto
# 38           M4G         East York
# 39           M4H         East York
# 40           M4J         East York
# 41           M4K      East Toronto
# 42           M4L      East Toronto
# 43           M4M      East Toronto
# 44           M4N   Central Toronto
# 45           M4P   Central Toronto
# 46           M4R   Central Toronto
# 47           M4S   Central Toronto
# 48           M4T   Central Toronto
# 49           M4V   Central Toronto
# 50           M4W  Downtown Toronto
# 51           M4X  Downtown Toronto
# 52           M4Y  Downtown Toronto
# 53           M5A  Downtown Toronto
# 54           M5B  Downtown Toronto
# 55           M5C  Downtown Toronto
# 56           M5E  Downtown Toronto
# 57           M5G  Downtown Toronto
# 58           M5H  Downtown Toronto
# 59           M5J  Downtown Toronto
# 60           M5K  Downtown Toronto
# 61           M5L  Downtown Toronto
# 62           M5M        North York
# 63           M5N   Central Toronto
# 64           M5P   Central Toronto
# 65           M5R   Central Toronto
# 66           M5S  Downtown Toronto
# 67           M5T  Downtown Toronto
# 68           M5V  Downtown Toronto
# 69           M5W  Downtown Toronto
# 70           M5X  Downtown Toronto
# 71           M6A        North York
# 72           M6B        North York
# 73           M6C              York
# 74           M6E              York
# 75           M6G  Downtown Toronto
# 76           M6H      West Toronto
# 77           M6J      West Toronto
# 78           M6K      West Toronto
# 79           M6L        North York
# 80           M6M              York
# 81           M6N              York
# 82           M6P      West Toronto
# 83           M6R      West Toronto
# 84           M6S      West Toronto
# 85           M7A      Queen's Park
# 86           M7R       Mississauga
# 87           M7Y      East Toronto
# 88           M8V         Etobicoke
# 89           M8W         Etobicoke
# 90           M8X         Etobicoke
# 91           M8Y         Etobicoke
# 92           M8Z         Etobicoke
# 93           M9A         Etobicoke
# 94           M9B         Etobicoke
# 95           M9C         Etobicoke
# 96           M9L        North York
# 97           M9M        North York
# 98           M9N              York
# 99           M9P         Etobicoke
# 100          M9R         Etobicoke
# 101          M9V         Etobicoke
# 102          M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude  \
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# 30                          CFB Toronto,Downsview East  43.737473 -79.464763
# 31                                      Downsview West  43.739015 -79.506944
# 32                                   Downsview Central  43.728496 -79.495697
# 33                                 Downsview Northwest  43.761631 -79.520999
# 34                                    Victoria Village  43.725882 -79.315572
# 35                      Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 36                                    Woodbine Heights  43.695344 -79.318389
# 37                                         The Beaches  43.676357 -79.293031
# 38                                             Leaside  43.709060 -79.363452
# 39                                    Thorncliffe Park  43.705369 -79.349372
# 40                                        East Toronto  43.685347 -79.338106
# 41                         The Danforth West,Riverdale  43.679557 -79.352188
# 42                       The Beaches West,India Bazaar  43.668999 -79.315572
# 43                                     Studio District  43.659526 -79.340923
# 44                                       Lawrence Park  43.728020 -79.388790
# 45                                    Davisville North  43.712751 -79.390197
# 46                                  North Toronto West  43.715383 -79.405678
# 47                                          Davisville  43.704324 -79.388790
# 48                          Moore Park,Summerhill East  43.689574 -79.383160
# 49   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 50                                            Rosedale  43.679563 -79.377529
# 51                          Cabbagetown,St. James Town  43.667967 -79.367675
# 52                                Church and Wellesley  43.665860 -79.383160
# 53                            Harbourfront,Regent Park  43.654260 -79.360636
# 54                             Ryerson,Garden District  43.657162 -79.378937
# 55                                      St. James Town  43.651494 -79.375418
# 56                                         Berczy Park  43.644771 -79.373306
# 57                                  Central Bay Street  43.657952 -79.387383
# 58                              Adelaide,King,Richmond  43.650571 -79.384568
# 59     Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 60             Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 61                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 62                    Bedford Park,Lawrence Manor East  43.733283 -79.419750
# 63                                            Roselawn  43.711695 -79.416936
# 64                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 65                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 66                       Harbord,University of Toronto  43.662696 -79.400049
# 67             Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 68   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 69                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 70               First Canadian Place,Underground city  43.648429 -79.382280
# 71                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 72                                           Glencairn  43.709577 -79.445073
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
#      Cluster labels       1st Most Common Venue  \
# 0               2.0        Fast Food Restaurant
# 1               4.0               Moving Target
# 2               0.0              Breakfast Spot
# 3               0.0                 Coffee Shop
# 4               0.0            Hakka Restaurant
# 5               0.0                  Playground
# 6               0.0            Department Store
# 7               0.0                    Bus Line
# 8               0.0         American Restaurant
# 9               0.0             College Stadium
# 10              0.0           Indian Restaurant
# 11              0.0              Breakfast Spot
# 12              0.0              Breakfast Spot
# 13              0.0                 Pizza Place
# 14              3.0                        Park
# 15              0.0        Fast Food Restaurant
# 16              NaN                         NaN
# 17              0.0        Fast Food Restaurant
# 18              0.0              Clothing Store
# 19              0.0         Japanese Restaurant
# 20              0.0                   Cafeteria
# 21              NaN                         NaN
# 22              0.0                 Coffee Shop
# 23              3.0                        Park
# 24              0.0                    Pharmacy
# 25              3.0        Fast Food Restaurant
# 26              0.0        Gym / Fitness Center
# 27              0.0                         Gym
# 28              0.0                 Coffee Shop
# 29              0.0          Falafel Restaurant
# 30              3.0                        Park
# 31              0.0               Grocery Store
# 32              0.0                  Food Truck
# 33              0.0              Discount Store
# 34              0.0                Intersection
# 35              0.0        Fast Food Restaurant
# 36              0.0                  Beer Store
# 37              0.0        Other Great Outdoors
# 38              0.0                 Coffee Shop
# 39              0.0           Indian Restaurant
# 40              3.0                        Park
# 41              0.0            Greek Restaurant
# 42              0.0                        Park
# 43              0.0                        Café
# 44              3.0                        Park
# 45              0.0        Gym / Fitness Center
# 46              0.0                 Coffee Shop
# 47              0.0                 Pizza Place
# 48              0.0                       Trail
# 49              0.0                 Coffee Shop
# 50              3.0                        Park
# 51              0.0                 Coffee Shop
# 52              0.0                 Coffee Shop
# 53              0.0                 Coffee Shop
# 54              0.0                 Coffee Shop
# 55              0.0                 Coffee Shop
# 56              0.0                 Coffee Shop
# 57              0.0                 Coffee Shop
# 58              0.0                 Coffee Shop
# 59              0.0                 Coffee Shop
# 60              0.0                 Coffee Shop
# 61              0.0                 Coffee Shop
# 62              0.0                 Coffee Shop
# 63              0.0                      Garden
# 64              3.0                       Trail
# 65              0.0                 Coffee Shop
# 66              0.0                        Café
# 67              0.0                        Café
# 68              0.0             Airport Service
# 69              0.0                 Coffee Shop
# 70              0.0                 Coffee Shop
# 71              0.0      Furniture / Home Store
# 72              0.0                        Park
# 73              0.0                       Trail
# 74              3.0                        Park
# 75              0.0               Grocery Store
# 76              0.0                    Pharmacy
# 77              0.0                         Bar
# 78              0.0              Breakfast Spot
# 79              3.0                        Park
# 80              0.0              Sandwich Place
# 81              0.0                    Bus Line
# 82              0.0          Mexican Restaurant
# 83              0.0              Breakfast Spot
# 84              0.0                 Coffee Shop
# 85              0.0                 Coffee Shop
# 86              0.0                 Coffee Shop
# 87              0.0        Gym / Fitness Center
# 88              0.0                      Bakery
# 89              0.0                 Pizza Place
# 90              1.0                        Park
# 91              0.0                   Locksmith
# 92              0.0              Hardware Store
# 93              NaN                         NaN
# 94              0.0                        Bank
# 95              0.0                   Pet Store
# 96              0.0         Empanada Restaurant
# 97              0.0  Construction & Landscaping
# 98              3.0                        Park
# 99              0.0                 Pizza Place
# 100             3.0                        Park
# 101             0.0               Grocery Store
# 102             0.0                         Bar
#
#              2nd Most Common Venue        3rd Most Common Venue  \
# 0                      Yoga Studio  Eastern European Restaurant
# 1                              Bar                  Yoga Studio
# 2              Rental Car Location                  Pizza Place
# 3                         Pharmacy            Korean Restaurant
# 4                  Thai Restaurant          Fried Chicken Joint
# 5                Convenience Store                  Yoga Studio
# 6                       Hobby Shop                  Coffee Shop
# 7             Fast Food Restaurant                 Intersection
# 8                            Motel               Farmers Market
# 9                             Café                 Skating Rink
# 10                       Pet Store        Vietnamese Restaurant
# 11                          Bakery                   Smoke Shop
# 12                          Lounge                 Skating Rink
# 13            Fast Food Restaurant                 Noodle House
# 14                      Playground          Dumpling Restaurant
# 15              Chinese Restaurant               Breakfast Spot
# 16                             NaN                          NaN
# 17                         Dog Run     Mediterranean Restaurant
# 18            Fast Food Restaurant                  Coffee Shop
# 19                            Bank                         Café
# 20                     Yoga Studio          Dumpling Restaurant
# 21                             NaN                          NaN
# 22                Ramen Restaurant                         Café
# 23                            Bank            Convenience Store
# 24                  Discount Store                Grocery Store
# 25                            Park            Food & Drink Shop
# 26            Caribbean Restaurant                         Café
# 27                Asian Restaurant                   Beer Store
# 28                   Deli / Bodega                  Pizza Place
# 29                  Massage Studio         Caribbean Restaurant
# 30                         Airport                     Bus Stop
# 31                            Park                         Bank
# 32                  Baseball Field                 Home Service
# 33            Gym / Fitness Center                Grocery Store
# 34                     Coffee Shop                 Hockey Arena
# 35                     Pizza Place                    Pet Store
# 36                     Curling Ice                         Park
# 37               Health Food Store                          Pub
# 38             Sporting Goods Shop                 Burger Joint
# 39                    Burger Joint                  Yoga Studio
# 40                     Pizza Place                  Coffee Shop
# 41                     Coffee Shop               Ice Cream Shop
# 42                  Ice Cream Shop                    Pet Store
# 43                     Coffee Shop                    Gastropub
# 44              Photography Studio                  Swim School
# 45                            Park               Sandwich Place
# 46                  Clothing Store          Sporting Goods Shop
# 47                  Sandwich Place                 Dessert Shop
# 48                      Playground                  Summer Camp
# 49                             Pub          American Restaurant
# 50                      Playground                     Building
# 51                      Restaurant                  Pizza Place
# 52             Japanese Restaurant             Sushi Restaurant
# 53                            Park                       Bakery
# 54                  Clothing Store               Cosmetics Shop
# 55                           Hotel           Italian Restaurant
# 56                    Cocktail Bar                         Café
# 57                            Café           Italian Restaurant
# 58                            Café                          Bar
# 59                           Hotel                     Aquarium
# 60                            Café                        Hotel
# 61                            Café                        Hotel
# 62              Italian Restaurant             Sushi Restaurant
# 63                     Music Venue                 Home Service
# 64                            Park             Sushi Restaurant
# 65                            Café               Sandwich Place
# 66                      Restaurant                    Bookstore
# 67   Vegetarian / Vegan Restaurant           Chinese Restaurant
# 68                Airport Terminal               Airport Lounge
# 69                            Café                   Restaurant
# 70                            Café                   Steakhouse
# 71                  Clothing Store            Accessories Store
# 72             Japanese Restaurant             Sushi Restaurant
# 73                           Field                      Dog Run
# 74                   Women's Store                       Market
# 75                            Café                         Park
# 76                          Bakery                  Supermarket
# 77                     Coffee Shop             Asian Restaurant
# 78                            Café                  Coffee Shop
# 79                          Bakery   Construction & Landscaping
# 80                      Restaurant            Convenience Store
# 81            Caribbean Restaurant                  Pizza Place
# 82                             Bar                         Café
# 83                       Gift Shop  Eastern European Restaurant
# 84                            Café                  Pizza Place
# 85                           Diner                          Gym
# 86                           Hotel         Gym / Fitness Center
# 87                          Garden                   Comic Shop
# 88             American Restaurant                         Café
# 89                             Gym               Sandwich Place
# 90                           River                    Drugstore
# 91                  Baseball Field             Business Service
# 92                   Tanning Salon                Grocery Store
# 93                             NaN                          NaN
# 94                     Golf Course                  Yoga Studio
# 95                     Pizza Place                   Beer Store
# 96                    Home Service                  Yoga Studio
# 97                  Baseball Field                  Yoga Studio
# 98                     Yoga Studio  Eastern European Restaurant
# 99                    Intersection               Sandwich Place
# 100                    Pizza Place            Mobile Phone Shop
# 101           Fast Food Restaurant                  Pizza Place
# 102            Rental Car Location                    Drugstore
#
#            4th Most Common Venue        5th Most Common Venue  \
# 0                       Dive Bar                      Dog Run
# 1                          Diner                     Dive Bar
# 2              Electronics Store               Medical Center
# 3                    Yoga Studio          Dumpling Restaurant
# 4                           Bank                       Bakery
# 5            Dumpling Restaurant               Discount Store
# 6             Chinese Restaurant                  Yoga Studio
# 7                  Metro Station                  Bus Station
# 8             Falafel Restaurant                  Event Space
# 9          General Entertainment                   Donut Shop
# 10     Latin American Restaurant           Chinese Restaurant
# 11     Middle Eastern Restaurant  Eastern European Restaurant
# 12                Clothing Store  Eastern European Restaurant
# 13           Fried Chicken Joint              Thai Restaurant
# 14                Discount Store                     Dive Bar
# 15             Indian Restaurant                Grocery Store
# 16                           NaN                          NaN
# 17                   Golf Course                         Pool
# 18                      Tea Room             Toy / Game Store
# 19            Chinese Restaurant                     Dive Bar
# 20                      Dive Bar                      Dog Run
# 21                           NaN                          NaN
# 22                   Pizza Place                   Restaurant
# 23                   Flower Shop                  Yoga Studio
# 24                   Pizza Place                  Coffee Shop
# 25           Dumpling Restaurant               Discount Store
# 26                Baseball Field             Basketball Court
# 27                   Coffee Shop         Fast Food Restaurant
# 28                    Restaurant             Sushi Restaurant
# 29                           Bar                  Coffee Shop
# 30           Dumpling Restaurant                     Dive Bar
# 31                 Shopping Mall                        Hotel
# 32                   Yoga Studio                      Dog Run
# 33            Athletics & Sports                 Liquor Store
# 34         Portuguese Restaurant          Dumpling Restaurant
# 35            Athletics & Sports                    Gastropub
# 36                      Pharmacy                  Video Store
# 37                  Neighborhood                        Trail
# 38        Furniture / Home Store             Sushi Restaurant
# 39                          Bank                 Liquor Store
# 40             Convenience Store          Dumpling Restaurant
# 41            Italian Restaurant       Furniture / Home Store
# 42                   Pizza Place                Movie Theater
# 43            Italian Restaurant                       Bakery
# 44                      Bus Line                    Drugstore
# 45             Food & Drink Shop             Asian Restaurant
# 46                   Yoga Studio                   Bagel Shop
# 47                   Coffee Shop           Italian Restaurant
# 48                   Yoga Studio               Discount Store
# 49                    Restaurant                   Bagel Shop
# 50                         Trail          Dumpling Restaurant
# 51                           Pub           Italian Restaurant
# 52                       Gay Bar                   Restaurant
# 53                          Café           Mexican Restaurant
# 54     Middle Eastern Restaurant                         Café
# 55                          Café                   Restaurant
# 56                   Cheese Shop                       Bakery
# 57                Ice Cream Shop               Sandwich Place
# 58               Thai Restaurant                   Steakhouse
# 59            Italian Restaurant                         Café
# 60                    Restaurant           Italian Restaurant
# 61           American Restaurant                   Restaurant
# 62              Greek Restaurant               Ice Cream Shop
# 63                     Drugstore               Discount Store
# 64                 Jewelry Store                  Yoga Studio
# 65                   Pizza Place                         Park
# 66           Japanese Restaurant                          Bar
# 67                           Bar           Mexican Restaurant
# 68                 Boat or Ferry                     Boutique
# 69                      Beer Bar                        Hotel
# 70                         Hotel                   Restaurant
# 71           Arts & Crafts Store             Fraternity House
# 72                   Pizza Place                          Pub
# 73                  Hockey Arena                  Yoga Studio
# 74          Fast Food Restaurant           Falafel Restaurant
# 75                   Coffee Shop                   Restaurant
# 76                Discount Store                          Bar
# 77                   Pizza Place                 Cocktail Bar
# 78                   Yoga Studio                          Bar
# 79              Basketball Court          Dumpling Restaurant
# 80         Check Cashing Service                  Yoga Studio
# 81             Convenience Store                  Yoga Studio
# 82                     Gastropub          Arts & Crafts Store
# 83                  Dessert Shop                          Bar
# 84            Italian Restaurant             Sushi Restaurant
# 85                          Park                Burrito Place
# 86           Fried Chicken Joint               Sandwich Place
# 87                          Park                  Pizza Place
# 88           Fried Chicken Joint               Sandwich Place
# 89                  Dance Studio                     Pharmacy
# 90                Discount Store                     Dive Bar
# 91                          Pool                  Yoga Studio
# 92          Fast Food Restaurant               Discount Store
# 93                           NaN                          NaN
# 94           Dumpling Restaurant                     Dive Bar
# 95                   Coffee Shop            Convenience Store
# 96           Dumpling Restaurant                     Dive Bar
# 97   Eastern European Restaurant                      Dog Run
# 98                      Dive Bar                      Dog Run
# 99                   Coffee Shop           Chinese Restaurant
# 100                    Drugstore               Discount Store
# 101               Sandwich Place                   Beer Store
# 102                  Yoga Studio                        Diner
#
#            6th Most Common Venue     7th Most Common Venue  \
# 0               Doner Restaurant                Donut Shop
# 1                        Dog Run          Doner Restaurant
# 2                   Intersection        Mexican Restaurant
# 3                       Dive Bar                   Dog Run
# 4           Caribbean Restaurant        Athletics & Sports
# 5                       Dive Bar                   Dog Run
# 6            Dumpling Restaurant                   Dog Run
# 7                   Soccer Field                    Bakery
# 8           Ethiopian Restaurant       Empanada Restaurant
# 9                 Discount Store                  Dive Bar
# 10                     Drugstore                  Dive Bar
# 11              Doner Restaurant                Donut Shop
# 12                       Dog Run          Doner Restaurant
# 13            Chinese Restaurant                      Bank
# 14                       Dog Run          Doner Restaurant
# 15               Bubble Tea Shop                  Pharmacy
# 16                           NaN                       NaN
# 17                   Yoga Studio       Dumpling Restaurant
# 18           Japanese Restaurant                    Bakery
# 19                       Dog Run          Doner Restaurant
# 20              Doner Restaurant                Donut Shop
# 21                           NaN                       NaN
# 22                Sandwich Place         Electronics Store
# 23           Dumpling Restaurant                   Dog Run
# 24                   Yoga Studio                 Drugstore
# 25                      Dive Bar                   Dog Run
# 26           Japanese Restaurant               Yoga Studio
# 27                Sandwich Place       Sporting Goods Shop
# 28                          Bank               Bridal Shop
# 29                   Yoga Studio                 Drugstore
# 30                       Dog Run          Doner Restaurant
# 31                    Donut Shop            Discount Store
# 32              Doner Restaurant                Donut Shop
# 33           Dumpling Restaurant                  Dive Bar
# 34                Discount Store                  Dive Bar
# 35                  Intersection                  Pharmacy
# 36                  Skating Rink                  Bus Stop
# 37           Empanada Restaurant         Electronics Store
# 38                 Shopping Mall                Sports Bar
# 39                          Park                  Pharmacy
# 40                Discount Store                  Dive Bar
# 41                     Bookstore                   Brewery
# 42                           Pub            Sandwich Place
# 43           American Restaurant               Yoga Studio
# 44                      Dive Bar                   Dog Run
# 45                         Hotel            Clothing Store
# 46                     Gift Shop             Metro Station
# 47                          Café          Sushi Restaurant
# 48                      Dive Bar                   Dog Run
# 49           Fried Chicken Joint                Sports Bar
# 50                Discount Store                  Dive Bar
# 51                   Flower Shop                    Bakery
# 52                   Men's Store  Mediterranean Restaurant
# 53                           Pub            Breakfast Spot
# 54                Ice Cream Shop                   Theater
# 55                  Cocktail Bar                  Beer Bar
# 56                      Beer Bar        Seafood Restaurant
# 57                  Burger Joint         Indian Restaurant
# 58                Breakfast Spot          Asian Restaurant
# 59                Scenic Lookout               Pizza Place
# 60                     Gastropub                       Bar
# 61                     Gastropub             Deli / Bodega
# 62                      Pharmacy               Pizza Place
# 63                      Dive Bar                   Dog Run
# 64                      Dive Bar                   Dog Run
# 65                     BBQ Joint            Cosmetics Shop
# 66                        Bakery     College Arts Building
# 67                   Coffee Shop       Dumpling Restaurant
# 68              Sculpture Garden                       Bar
# 69          Fast Food Restaurant        Seafood Restaurant
# 70                 Deli / Bodega                       Gym
# 71                   Event Space        Miscellaneous Shop
# 72                   Yoga Studio          Doner Restaurant
# 73                      Dive Bar          Doner Restaurant
# 74                   Event Space      Ethiopian Restaurant
# 75                    Baby Store        Athletics & Sports
# 76                          Park                      Bank
# 77         Vietnamese Restaurant         French Restaurant
# 78                 Burrito Place                Restaurant
# 79                       Dog Run          Doner Restaurant
# 80                     Drugstore                  Dive Bar
# 81                      Dive Bar                   Dog Run
# 82                         Diner       Fried Chicken Joint
# 83                          Bank        Italian Restaurant
# 84                 Smoothie Shop                Restaurant
# 85            Italian Restaurant       Japanese Restaurant
# 86                 Burrito Place  Mediterranean Restaurant
# 87                    Restaurant             Burrito Place
# 88            Seafood Restaurant                Restaurant
# 89                   Coffee Shop              Skating Rink
# 90                       Dog Run          Doner Restaurant
# 91   Eastern European Restaurant          Doner Restaurant
# 92             Convenience Store            Sandwich Place
# 93                           NaN                       NaN
# 94                       Dog Run          Doner Restaurant
# 95                          Café              Liquor Store
# 96                       Dog Run          Doner Restaurant
# 97              Doner Restaurant                Donut Shop
# 98              Doner Restaurant                Donut Shop
# 99                    Donut Shop            Discount Store
# 100                     Dive Bar                   Dog Run
# 101                  Coffee Shop       Fried Chicken Joint
# 102                     Dive Bar                   Dog Run
#
#            8th Most Common Venue        9th Most Common Venue  \
# 0                      Drugstore          Dumpling Restaurant
# 1                     Donut Shop                    Drugstore
# 2                     Donut Shop               Discount Store
# 3               Doner Restaurant                   Donut Shop
# 4                         Lounge                 Cupcake Shop
# 5               Doner Restaurant                   Donut Shop
# 6               Doner Restaurant                   Donut Shop
# 7                           Park                    Gift Shop
# 8              Electronics Store  Eastern European Restaurant
# 9                        Dog Run             Doner Restaurant
# 10                       Dog Run             Doner Restaurant
# 11                     Drugstore          Dumpling Restaurant
# 12                    Donut Shop                    Drugstore
# 13            Italian Restaurant                     Pharmacy
# 14                    Donut Shop                    Drugstore
# 15                Cosmetics Shop                  Pizza Place
# 16                           NaN                          NaN
# 17                      Dive Bar             Doner Restaurant
# 18                    Food Court            Convenience Store
# 19                    Donut Shop                    Drugstore
# 20                     Drugstore  Eastern European Restaurant
# 21                           NaN                          NaN
# 22                     Juice Bar         Fast Food Restaurant
# 23              Doner Restaurant                   Donut Shop
# 24                      Dive Bar                      Dog Run
# 25              Doner Restaurant                   Donut Shop
# 26                     Drugstore             Doner Restaurant
# 27                     Bike Shop               Discount Store
# 28                         Diner          Fried Chicken Joint
# 29                       Dog Run             Doner Restaurant
# 30                    Donut Shop                    Drugstore
# 31                      Dive Bar                      Dog Run
# 32                     Drugstore          Dumpling Restaurant
# 33                       Dog Run             Doner Restaurant
# 34                       Dog Run             Doner Restaurant
# 35                          Café                         Bank
# 36                Cosmetics Shop           Athletics & Sports
# 37   Eastern European Restaurant          Dumpling Restaurant
# 38                    Beer Store                    Bike Shop
# 39                   Coffee Shop                  Pizza Place
# 40                       Dog Run             Doner Restaurant
# 41               Bubble Tea Shop                   Restaurant
# 42                 Burrito Place                 Burger Joint
# 43             Convenience Store                      Brewery
# 44              Doner Restaurant                   Donut Shop
# 45                Breakfast Spot                Grocery Store
# 46            Mexican Restaurant                        Diner
# 47                          Park           Seafood Restaurant
# 48              Doner Restaurant                   Donut Shop
# 49                   Supermarket                  Pizza Place
# 50                       Dog Run             Doner Restaurant
# 51                          Café                       Market
# 52                           Gym                    Gastropub
# 53             Electronics Store        Performing Arts Venue
# 54          Fast Food Restaurant                   Restaurant
# 55                Cosmetics Shop               Clothing Store
# 56                    Steakhouse               Farmers Market
# 57                           Bar              Bubble Tea Shop
# 58           American Restaurant                          Gym
# 59                        Bakery          Sporting Goods Shop
# 60                        Bakery                Deli / Bodega
# 61                    Steakhouse                       Bakery
# 62                           Pub                   Restaurant
# 63              Doner Restaurant                   Donut Shop
# 64              Doner Restaurant                   Donut Shop
# 65                      Pharmacy                          Pub
# 66             French Restaurant               Sandwich Place
# 67                        Bakery        Vietnamese Restaurant
# 68               Harbor / Marina                 Airport Gate
# 69                  Cocktail Bar          Japanese Restaurant
# 70           American Restaurant             Asian Restaurant
# 71                   Coffee Shop                     Boutique
# 72                Discount Store                     Dive Bar
# 73                    Donut Shop                    Drugstore
# 74           Empanada Restaurant            Electronics Store
# 75            Italian Restaurant                        Diner
# 76          Gym / Fitness Center                      Brewery
# 77                   Men's Store                         Café
# 78          Caribbean Restaurant                 Climbing Gym
# 79                    Donut Shop                    Drugstore
# 80                       Dog Run             Doner Restaurant
# 81              Doner Restaurant                   Donut Shop
# 82                        Bakery    Cajun / Creole Restaurant
# 83                    Restaurant                Movie Theater
# 84                     Bookstore    Latin American Restaurant
# 85                           Spa         Fast Food Restaurant
# 86           American Restaurant    Middle Eastern Restaurant
# 87                    Skate Park                   Smoke Shop
# 88                   Pizza Place         Fast Food Restaurant
# 89                           Pub             Doner Restaurant
# 90                    Donut Shop          Dumpling Restaurant
# 91                    Donut Shop                    Drugstore
# 92                 Burrito Place                 Burger Joint
# 93                           NaN                          NaN
# 94                    Donut Shop                    Drugstore
# 95                      Pharmacy          Empanada Restaurant
# 96                    Donut Shop                    Drugstore
# 97                     Drugstore          Dumpling Restaurant
# 98                     Drugstore          Dumpling Restaurant
# 99                      Dive Bar                      Dog Run
# 100             Doner Restaurant                   Donut Shop
# 101                     Pharmacy            Electronics Store
# 102             Doner Restaurant                   Donut Shop
#
#           10th Most Common Venue
# 0              Electronics Store
# 1            Dumpling Restaurant
# 2                       Dive Bar
# 3                      Drugstore
# 4                    Curling Ice
# 5                      Drugstore
# 6                      Drugstore
# 7              German Restaurant
# 8                          Diner
# 9                      Drugstore
# 10                    Donut Shop
# 11             Electronics Store
# 12           Dumpling Restaurant
# 13   Eastern European Restaurant
# 14   Eastern European Restaurant
# 15                Sandwich Place
# 16                           NaN
# 17                    Donut Shop
# 18                    Restaurant
# 19                   Yoga Studio
# 20                         Field
# 21                           NaN
# 22           Japanese Restaurant
# 23                     Drugstore
# 24              Doner Restaurant
# 25                     Drugstore
# 26                    Donut Shop
# 27                    Restaurant
# 28            Frozen Yogurt Shop
# 29                    Donut Shop
# 30   Eastern European Restaurant
# 31              Doner Restaurant
# 32   Eastern European Restaurant
# 33                    Donut Shop
# 34                    Donut Shop
# 35          Gym / Fitness Center
# 36                  Dance Studio
# 37                     Drugstore
# 38             Fish & Chips Shop
# 39                Sandwich Place
# 40                    Donut Shop
# 41          Caribbean Restaurant
# 42                       Brewery
# 43            Seafood Restaurant
# 44           Dumpling Restaurant
# 45                           Gym
# 46                  Dessert Shop
# 47                    Restaurant
# 48                     Drugstore
# 49              Sushi Restaurant
# 50                    Donut Shop
# 51                Breakfast Spot
# 52                         Hotel
# 53                           Spa
# 54                         Diner
# 55                Breakfast Spot
# 56   Eastern European Restaurant
# 57                        Bakery
# 58                         Hotel
# 59                       Brewery
# 60           American Restaurant
# 61                           Gym
# 62                          Café
# 63           Dumpling Restaurant
# 64                     Drugstore
# 65                  Burger Joint
# 66                    Beer Store
# 67                   Gaming Cafe
# 68            Airport Food Court
# 69                Farmers Market
# 70                           Bar
# 71                 Women's Store
# 72                       Dog Run
# 73           Dumpling Restaurant
# 74                         Diner
# 75                     Nightclub
# 76     Middle Eastern Restaurant
# 77                    Restaurant
# 78                     Pet Store
# 79   Eastern European Restaurant
# 80                    Donut Shop
# 81                     Drugstore
# 82        Furniture / Home Store
# 83                       Dog Run
# 84             Fish & Chips Shop
# 85            Seafood Restaurant
# 86                     Drugstore
# 87                       Brewery
# 88                  Liquor Store
# 89                Discount Store
# 90            Dim Sum Restaurant
# 91           Dumpling Restaurant
# 92                   Social Club
# 93                           NaN
# 94   Eastern European Restaurant
# 95          Ethiopian Restaurant
# 96             Electronics Store
# 97             Electronics Store
# 98             Electronics Store
# 99              Doner Restaurant
# 100          Dumpling Restaurant
# 101          Empanada Restaurant
# 102          Dumpling Restaurant

# %%
#drop rows with cluster label as NaN
toronto_merged.dropna(subset=['Cluster labels'], inplace=True)
toronto_merged
# Out:
#     Neighborhood           Borough  \
# 0            M1B       Scarborough
# 1            M1C       Scarborough
# 2            M1E       Scarborough
# 3            M1G       Scarborough
# 4            M1H       Scarborough
# 5            M1J       Scarborough
# 6            M1K       Scarborough
# 7            M1L       Scarborough
# 8            M1M       Scarborough
# 9            M1N       Scarborough
# 10           M1P       Scarborough
# 11           M1R       Scarborough
# 12           M1S       Scarborough
# 13           M1T       Scarborough
# 14           M1V       Scarborough
# 15           M1W       Scarborough
# 17           M2H        North York
# 18           M2J        North York
# 19           M2K        North York
# 20           M2L        North York
# 22           M2N        North York
# 23           M2P        North York
# 24           M2R        North York
# 25           M3A        North York
# 26           M3B        North York
# 27           M3C        North York
# 28           M3H        North York
# 29           M3J        North York
# 30           M3K        North York
# 31           M3L        North York
# 32           M3M        North York
# 33           M3N        North York
# 34           M4A        North York
# 35           M4B         East York
# 36           M4C         East York
# 37           M4E      East Toronto
# 38           M4G         East York
# 39           M4H         East York
# 40           M4J         East York
# 41           M4K      East Toronto
# 42           M4L      East Toronto
# 43           M4M      East Toronto
# 44           M4N   Central Toronto
# 45           M4P   Central Toronto
# 46           M4R   Central Toronto
# 47           M4S   Central Toronto
# 48           M4T   Central Toronto
# 49           M4V   Central Toronto
# 50           M4W  Downtown Toronto
# 51           M4X  Downtown Toronto
# 52           M4Y  Downtown Toronto
# 53           M5A  Downtown Toronto
# 54           M5B  Downtown Toronto
# 55           M5C  Downtown Toronto
# 56           M5E  Downtown Toronto
# 57           M5G  Downtown Toronto
# 58           M5H  Downtown Toronto
# 59           M5J  Downtown Toronto
# 60           M5K  Downtown Toronto
# 61           M5L  Downtown Toronto
# 62           M5M        North York
# 63           M5N   Central Toronto
# 64           M5P   Central Toronto
# 65           M5R   Central Toronto
# 66           M5S  Downtown Toronto
# 67           M5T  Downtown Toronto
# 68           M5V  Downtown Toronto
# 69           M5W  Downtown Toronto
# 70           M5X  Downtown Toronto
# 71           M6A        North York
# 72           M6B        North York
# 73           M6C              York
# 74           M6E              York
# 75           M6G  Downtown Toronto
# 76           M6H      West Toronto
# 77           M6J      West Toronto
# 78           M6K      West Toronto
# 79           M6L        North York
# 80           M6M              York
# 81           M6N              York
# 82           M6P      West Toronto
# 83           M6R      West Toronto
# 84           M6S      West Toronto
# 85           M7A      Queen's Park
# 86           M7R       Mississauga
# 87           M7Y      East Toronto
# 88           M8V         Etobicoke
# 89           M8W         Etobicoke
# 90           M8X         Etobicoke
# 91           M8Y         Etobicoke
# 92           M8Z         Etobicoke
# 94           M9B         Etobicoke
# 95           M9C         Etobicoke
# 96           M9L        North York
# 97           M9M        North York
# 98           M9N              York
# 99           M9P         Etobicoke
# 100          M9R         Etobicoke
# 101          M9V         Etobicoke
# 102          M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude  \
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# 30                          CFB Toronto,Downsview East  43.737473 -79.464763
# 31                                      Downsview West  43.739015 -79.506944
# 32                                   Downsview Central  43.728496 -79.495697
# 33                                 Downsview Northwest  43.761631 -79.520999
# 34                                    Victoria Village  43.725882 -79.315572
# 35                      Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 36                                    Woodbine Heights  43.695344 -79.318389
# 37                                         The Beaches  43.676357 -79.293031
# 38                                             Leaside  43.709060 -79.363452
# 39                                    Thorncliffe Park  43.705369 -79.349372
# 40                                        East Toronto  43.685347 -79.338106
# 41                         The Danforth West,Riverdale  43.679557 -79.352188
# 42                       The Beaches West,India Bazaar  43.668999 -79.315572
# 43                                     Studio District  43.659526 -79.340923
# 44                                       Lawrence Park  43.728020 -79.388790
# 45                                    Davisville North  43.712751 -79.390197
# 46                                  North Toronto West  43.715383 -79.405678
# 47                                          Davisville  43.704324 -79.388790
# 48                          Moore Park,Summerhill East  43.689574 -79.383160
# 49   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 50                                            Rosedale  43.679563 -79.377529
# 51                          Cabbagetown,St. James Town  43.667967 -79.367675
# 52                                Church and Wellesley  43.665860 -79.383160
# 53                            Harbourfront,Regent Park  43.654260 -79.360636
# 54                             Ryerson,Garden District  43.657162 -79.378937
# 55                                      St. James Town  43.651494 -79.375418
# 56                                         Berczy Park  43.644771 -79.373306
# 57                                  Central Bay Street  43.657952 -79.387383
# 58                              Adelaide,King,Richmond  43.650571 -79.384568
# 59     Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 60             Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 61                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 62                    Bedford Park,Lawrence Manor East  43.733283 -79.419750
# 63                                            Roselawn  43.711695 -79.416936
# 64                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 65                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 66                       Harbord,University of Toronto  43.662696 -79.400049
# 67             Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 68   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 69                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 70               First Canadian Place,Underground city  43.648429 -79.382280
# 71                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 72                                           Glencairn  43.709577 -79.445073
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
#      Cluster labels       1st Most Common Venue  \
# 0               2.0        Fast Food Restaurant
# 1               4.0               Moving Target
# 2               0.0              Breakfast Spot
# 3               0.0                 Coffee Shop
# 4               0.0            Hakka Restaurant
# 5               0.0                  Playground
# 6               0.0            Department Store
# 7               0.0                    Bus Line
# 8               0.0         American Restaurant
# 9               0.0             College Stadium
# 10              0.0           Indian Restaurant
# 11              0.0              Breakfast Spot
# 12              0.0              Breakfast Spot
# 13              0.0                 Pizza Place
# 14              3.0                        Park
# 15              0.0        Fast Food Restaurant
# 17              0.0        Fast Food Restaurant
# 18              0.0              Clothing Store
# 19              0.0         Japanese Restaurant
# 20              0.0                   Cafeteria
# 22              0.0                 Coffee Shop
# 23              3.0                        Park
# 24              0.0                    Pharmacy
# 25              3.0        Fast Food Restaurant
# 26              0.0        Gym / Fitness Center
# 27              0.0                         Gym
# 28              0.0                 Coffee Shop
# 29              0.0          Falafel Restaurant
# 30              3.0                        Park
# 31              0.0               Grocery Store
# 32              0.0                  Food Truck
# 33              0.0              Discount Store
# 34              0.0                Intersection
# 35              0.0        Fast Food Restaurant
# 36              0.0                  Beer Store
# 37              0.0        Other Great Outdoors
# 38              0.0                 Coffee Shop
# 39              0.0           Indian Restaurant
# 40              3.0                        Park
# 41              0.0            Greek Restaurant
# 42              0.0                        Park
# 43              0.0                        Café
# 44              3.0                        Park
# 45              0.0        Gym / Fitness Center
# 46              0.0                 Coffee Shop
# 47              0.0                 Pizza Place
# 48              0.0                       Trail
# 49              0.0                 Coffee Shop
# 50              3.0                        Park
# 51              0.0                 Coffee Shop
# 52              0.0                 Coffee Shop
# 53              0.0                 Coffee Shop
# 54              0.0                 Coffee Shop
# 55              0.0                 Coffee Shop
# 56              0.0                 Coffee Shop
# 57              0.0                 Coffee Shop
# 58              0.0                 Coffee Shop
# 59              0.0                 Coffee Shop
# 60              0.0                 Coffee Shop
# 61              0.0                 Coffee Shop
# 62              0.0                 Coffee Shop
# 63              0.0                      Garden
# 64              3.0                       Trail
# 65              0.0                 Coffee Shop
# 66              0.0                        Café
# 67              0.0                        Café
# 68              0.0             Airport Service
# 69              0.0                 Coffee Shop
# 70              0.0                 Coffee Shop
# 71              0.0      Furniture / Home Store
# 72              0.0                        Park
# 73              0.0                       Trail
# 74              3.0                        Park
# 75              0.0               Grocery Store
# 76              0.0                    Pharmacy
# 77              0.0                         Bar
# 78              0.0              Breakfast Spot
# 79              3.0                        Park
# 80              0.0              Sandwich Place
# 81              0.0                    Bus Line
# 82              0.0          Mexican Restaurant
# 83              0.0              Breakfast Spot
# 84              0.0                 Coffee Shop
# 85              0.0                 Coffee Shop
# 86              0.0                 Coffee Shop
# 87              0.0        Gym / Fitness Center
# 88              0.0                      Bakery
# 89              0.0                 Pizza Place
# 90              1.0                        Park
# 91              0.0                   Locksmith
# 92              0.0              Hardware Store
# 94              0.0                        Bank
# 95              0.0                   Pet Store
# 96              0.0         Empanada Restaurant
# 97              0.0  Construction & Landscaping
# 98              3.0                        Park
# 99              0.0                 Pizza Place
# 100             3.0                        Park
# 101             0.0               Grocery Store
# 102             0.0                         Bar
#
#              2nd Most Common Venue        3rd Most Common Venue  \
# 0                      Yoga Studio  Eastern European Restaurant
# 1                              Bar                  Yoga Studio
# 2              Rental Car Location                  Pizza Place
# 3                         Pharmacy            Korean Restaurant
# 4                  Thai Restaurant          Fried Chicken Joint
# 5                Convenience Store                  Yoga Studio
# 6                       Hobby Shop                  Coffee Shop
# 7             Fast Food Restaurant                 Intersection
# 8                            Motel               Farmers Market
# 9                             Café                 Skating Rink
# 10                       Pet Store        Vietnamese Restaurant
# 11                          Bakery                   Smoke Shop
# 12                          Lounge                 Skating Rink
# 13            Fast Food Restaurant                 Noodle House
# 14                      Playground          Dumpling Restaurant
# 15              Chinese Restaurant               Breakfast Spot
# 17                         Dog Run     Mediterranean Restaurant
# 18            Fast Food Restaurant                  Coffee Shop
# 19                            Bank                         Café
# 20                     Yoga Studio          Dumpling Restaurant
# 22                Ramen Restaurant                         Café
# 23                            Bank            Convenience Store
# 24                  Discount Store                Grocery Store
# 25                            Park            Food & Drink Shop
# 26            Caribbean Restaurant                         Café
# 27                Asian Restaurant                   Beer Store
# 28                   Deli / Bodega                  Pizza Place
# 29                  Massage Studio         Caribbean Restaurant
# 30                         Airport                     Bus Stop
# 31                            Park                         Bank
# 32                  Baseball Field                 Home Service
# 33            Gym / Fitness Center                Grocery Store
# 34                     Coffee Shop                 Hockey Arena
# 35                     Pizza Place                    Pet Store
# 36                     Curling Ice                         Park
# 37               Health Food Store                          Pub
# 38             Sporting Goods Shop                 Burger Joint
# 39                    Burger Joint                  Yoga Studio
# 40                     Pizza Place                  Coffee Shop
# 41                     Coffee Shop               Ice Cream Shop
# 42                  Ice Cream Shop                    Pet Store
# 43                     Coffee Shop                    Gastropub
# 44              Photography Studio                  Swim School
# 45                            Park               Sandwich Place
# 46                  Clothing Store          Sporting Goods Shop
# 47                  Sandwich Place                 Dessert Shop
# 48                      Playground                  Summer Camp
# 49                             Pub          American Restaurant
# 50                      Playground                     Building
# 51                      Restaurant                  Pizza Place
# 52             Japanese Restaurant             Sushi Restaurant
# 53                            Park                       Bakery
# 54                  Clothing Store               Cosmetics Shop
# 55                           Hotel           Italian Restaurant
# 56                    Cocktail Bar                         Café
# 57                            Café           Italian Restaurant
# 58                            Café                          Bar
# 59                           Hotel                     Aquarium
# 60                            Café                        Hotel
# 61                            Café                        Hotel
# 62              Italian Restaurant             Sushi Restaurant
# 63                     Music Venue                 Home Service
# 64                            Park             Sushi Restaurant
# 65                            Café               Sandwich Place
# 66                      Restaurant                    Bookstore
# 67   Vegetarian / Vegan Restaurant           Chinese Restaurant
# 68                Airport Terminal               Airport Lounge
# 69                            Café                   Restaurant
# 70                            Café                   Steakhouse
# 71                  Clothing Store            Accessories Store
# 72             Japanese Restaurant             Sushi Restaurant
# 73                           Field                      Dog Run
# 74                   Women's Store                       Market
# 75                            Café                         Park
# 76                          Bakery                  Supermarket
# 77                     Coffee Shop             Asian Restaurant
# 78                            Café                  Coffee Shop
# 79                          Bakery   Construction & Landscaping
# 80                      Restaurant            Convenience Store
# 81            Caribbean Restaurant                  Pizza Place
# 82                             Bar                         Café
# 83                       Gift Shop  Eastern European Restaurant
# 84                            Café                  Pizza Place
# 85                           Diner                          Gym
# 86                           Hotel         Gym / Fitness Center
# 87                          Garden                   Comic Shop
# 88             American Restaurant                         Café
# 89                             Gym               Sandwich Place
# 90                           River                    Drugstore
# 91                  Baseball Field             Business Service
# 92                   Tanning Salon                Grocery Store
# 94                     Golf Course                  Yoga Studio
# 95                     Pizza Place                   Beer Store
# 96                    Home Service                  Yoga Studio
# 97                  Baseball Field                  Yoga Studio
# 98                     Yoga Studio  Eastern European Restaurant
# 99                    Intersection               Sandwich Place
# 100                    Pizza Place            Mobile Phone Shop
# 101           Fast Food Restaurant                  Pizza Place
# 102            Rental Car Location                    Drugstore
#
#            4th Most Common Venue        5th Most Common Venue  \
# 0                       Dive Bar                      Dog Run
# 1                          Diner                     Dive Bar
# 2              Electronics Store               Medical Center
# 3                    Yoga Studio          Dumpling Restaurant
# 4                           Bank                       Bakery
# 5            Dumpling Restaurant               Discount Store
# 6             Chinese Restaurant                  Yoga Studio
# 7                  Metro Station                  Bus Station
# 8             Falafel Restaurant                  Event Space
# 9          General Entertainment                   Donut Shop
# 10     Latin American Restaurant           Chinese Restaurant
# 11     Middle Eastern Restaurant  Eastern European Restaurant
# 12                Clothing Store  Eastern European Restaurant
# 13           Fried Chicken Joint              Thai Restaurant
# 14                Discount Store                     Dive Bar
# 15             Indian Restaurant                Grocery Store
# 17                   Golf Course                         Pool
# 18                      Tea Room             Toy / Game Store
# 19            Chinese Restaurant                     Dive Bar
# 20                      Dive Bar                      Dog Run
# 22                   Pizza Place                   Restaurant
# 23                   Flower Shop                  Yoga Studio
# 24                   Pizza Place                  Coffee Shop
# 25           Dumpling Restaurant               Discount Store
# 26                Baseball Field             Basketball Court
# 27                   Coffee Shop         Fast Food Restaurant
# 28                    Restaurant             Sushi Restaurant
# 29                           Bar                  Coffee Shop
# 30           Dumpling Restaurant                     Dive Bar
# 31                 Shopping Mall                        Hotel
# 32                   Yoga Studio                      Dog Run
# 33            Athletics & Sports                 Liquor Store
# 34         Portuguese Restaurant          Dumpling Restaurant
# 35            Athletics & Sports                    Gastropub
# 36                      Pharmacy                  Video Store
# 37                  Neighborhood                        Trail
# 38        Furniture / Home Store             Sushi Restaurant
# 39                          Bank                 Liquor Store
# 40             Convenience Store          Dumpling Restaurant
# 41            Italian Restaurant       Furniture / Home Store
# 42                   Pizza Place                Movie Theater
# 43            Italian Restaurant                       Bakery
# 44                      Bus Line                    Drugstore
# 45             Food & Drink Shop             Asian Restaurant
# 46                   Yoga Studio                   Bagel Shop
# 47                   Coffee Shop           Italian Restaurant
# 48                   Yoga Studio               Discount Store
# 49                    Restaurant                   Bagel Shop
# 50                         Trail          Dumpling Restaurant
# 51                           Pub           Italian Restaurant
# 52                       Gay Bar                   Restaurant
# 53                          Café           Mexican Restaurant
# 54     Middle Eastern Restaurant                         Café
# 55                          Café                   Restaurant
# 56                   Cheese Shop                       Bakery
# 57                Ice Cream Shop               Sandwich Place
# 58               Thai Restaurant                   Steakhouse
# 59            Italian Restaurant                         Café
# 60                    Restaurant           Italian Restaurant
# 61           American Restaurant                   Restaurant
# 62              Greek Restaurant               Ice Cream Shop
# 63                     Drugstore               Discount Store
# 64                 Jewelry Store                  Yoga Studio
# 65                   Pizza Place                         Park
# 66           Japanese Restaurant                          Bar
# 67                           Bar           Mexican Restaurant
# 68                 Boat or Ferry                     Boutique
# 69                      Beer Bar                        Hotel
# 70                         Hotel                   Restaurant
# 71           Arts & Crafts Store             Fraternity House
# 72                   Pizza Place                          Pub
# 73                  Hockey Arena                  Yoga Studio
# 74          Fast Food Restaurant           Falafel Restaurant
# 75                   Coffee Shop                   Restaurant
# 76                Discount Store                          Bar
# 77                   Pizza Place                 Cocktail Bar
# 78                   Yoga Studio                          Bar
# 79              Basketball Court          Dumpling Restaurant
# 80         Check Cashing Service                  Yoga Studio
# 81             Convenience Store                  Yoga Studio
# 82                     Gastropub          Arts & Crafts Store
# 83                  Dessert Shop                          Bar
# 84            Italian Restaurant             Sushi Restaurant
# 85                          Park                Burrito Place
# 86           Fried Chicken Joint               Sandwich Place
# 87                          Park                  Pizza Place
# 88           Fried Chicken Joint               Sandwich Place
# 89                  Dance Studio                     Pharmacy
# 90                Discount Store                     Dive Bar
# 91                          Pool                  Yoga Studio
# 92          Fast Food Restaurant               Discount Store
# 94           Dumpling Restaurant                     Dive Bar
# 95                   Coffee Shop            Convenience Store
# 96           Dumpling Restaurant                     Dive Bar
# 97   Eastern European Restaurant                      Dog Run
# 98                      Dive Bar                      Dog Run
# 99                   Coffee Shop           Chinese Restaurant
# 100                    Drugstore               Discount Store
# 101               Sandwich Place                   Beer Store
# 102                  Yoga Studio                        Diner
#
#            6th Most Common Venue     7th Most Common Venue  \
# 0               Doner Restaurant                Donut Shop
# 1                        Dog Run          Doner Restaurant
# 2                   Intersection        Mexican Restaurant
# 3                       Dive Bar                   Dog Run
# 4           Caribbean Restaurant        Athletics & Sports
# 5                       Dive Bar                   Dog Run
# 6            Dumpling Restaurant                   Dog Run
# 7                   Soccer Field                    Bakery
# 8           Ethiopian Restaurant       Empanada Restaurant
# 9                 Discount Store                  Dive Bar
# 10                     Drugstore                  Dive Bar
# 11              Doner Restaurant                Donut Shop
# 12                       Dog Run          Doner Restaurant
# 13            Chinese Restaurant                      Bank
# 14                       Dog Run          Doner Restaurant
# 15               Bubble Tea Shop                  Pharmacy
# 17                   Yoga Studio       Dumpling Restaurant
# 18           Japanese Restaurant                    Bakery
# 19                       Dog Run          Doner Restaurant
# 20              Doner Restaurant                Donut Shop
# 22                Sandwich Place         Electronics Store
# 23           Dumpling Restaurant                   Dog Run
# 24                   Yoga Studio                 Drugstore
# 25                      Dive Bar                   Dog Run
# 26           Japanese Restaurant               Yoga Studio
# 27                Sandwich Place       Sporting Goods Shop
# 28                          Bank               Bridal Shop
# 29                   Yoga Studio                 Drugstore
# 30                       Dog Run          Doner Restaurant
# 31                    Donut Shop            Discount Store
# 32              Doner Restaurant                Donut Shop
# 33           Dumpling Restaurant                  Dive Bar
# 34                Discount Store                  Dive Bar
# 35                  Intersection                  Pharmacy
# 36                  Skating Rink                  Bus Stop
# 37           Empanada Restaurant         Electronics Store
# 38                 Shopping Mall                Sports Bar
# 39                          Park                  Pharmacy
# 40                Discount Store                  Dive Bar
# 41                     Bookstore                   Brewery
# 42                           Pub            Sandwich Place
# 43           American Restaurant               Yoga Studio
# 44                      Dive Bar                   Dog Run
# 45                         Hotel            Clothing Store
# 46                     Gift Shop             Metro Station
# 47                          Café          Sushi Restaurant
# 48                      Dive Bar                   Dog Run
# 49           Fried Chicken Joint                Sports Bar
# 50                Discount Store                  Dive Bar
# 51                   Flower Shop                    Bakery
# 52                   Men's Store  Mediterranean Restaurant
# 53                           Pub            Breakfast Spot
# 54                Ice Cream Shop                   Theater
# 55                  Cocktail Bar                  Beer Bar
# 56                      Beer Bar        Seafood Restaurant
# 57                  Burger Joint         Indian Restaurant
# 58                Breakfast Spot          Asian Restaurant
# 59                Scenic Lookout               Pizza Place
# 60                     Gastropub                       Bar
# 61                     Gastropub             Deli / Bodega
# 62                      Pharmacy               Pizza Place
# 63                      Dive Bar                   Dog Run
# 64                      Dive Bar                   Dog Run
# 65                     BBQ Joint            Cosmetics Shop
# 66                        Bakery     College Arts Building
# 67                   Coffee Shop       Dumpling Restaurant
# 68              Sculpture Garden                       Bar
# 69          Fast Food Restaurant        Seafood Restaurant
# 70                 Deli / Bodega                       Gym
# 71                   Event Space        Miscellaneous Shop
# 72                   Yoga Studio          Doner Restaurant
# 73                      Dive Bar          Doner Restaurant
# 74                   Event Space      Ethiopian Restaurant
# 75                    Baby Store        Athletics & Sports
# 76                          Park                      Bank
# 77         Vietnamese Restaurant         French Restaurant
# 78                 Burrito Place                Restaurant
# 79                       Dog Run          Doner Restaurant
# 80                     Drugstore                  Dive Bar
# 81                      Dive Bar                   Dog Run
# 82                         Diner       Fried Chicken Joint
# 83                          Bank        Italian Restaurant
# 84                 Smoothie Shop                Restaurant
# 85            Italian Restaurant       Japanese Restaurant
# 86                 Burrito Place  Mediterranean Restaurant
# 87                    Restaurant             Burrito Place
# 88            Seafood Restaurant                Restaurant
# 89                   Coffee Shop              Skating Rink
# 90                       Dog Run          Doner Restaurant
# 91   Eastern European Restaurant          Doner Restaurant
# 92             Convenience Store            Sandwich Place
# 94                       Dog Run          Doner Restaurant
# 95                          Café              Liquor Store
# 96                       Dog Run          Doner Restaurant
# 97              Doner Restaurant                Donut Shop
# 98              Doner Restaurant                Donut Shop
# 99                    Donut Shop            Discount Store
# 100                     Dive Bar                   Dog Run
# 101                  Coffee Shop       Fried Chicken Joint
# 102                     Dive Bar                   Dog Run
#
#            8th Most Common Venue        9th Most Common Venue  \
# 0                      Drugstore          Dumpling Restaurant
# 1                     Donut Shop                    Drugstore
# 2                     Donut Shop               Discount Store
# 3               Doner Restaurant                   Donut Shop
# 4                         Lounge                 Cupcake Shop
# 5               Doner Restaurant                   Donut Shop
# 6               Doner Restaurant                   Donut Shop
# 7                           Park                    Gift Shop
# 8              Electronics Store  Eastern European Restaurant
# 9                        Dog Run             Doner Restaurant
# 10                       Dog Run             Doner Restaurant
# 11                     Drugstore          Dumpling Restaurant
# 12                    Donut Shop                    Drugstore
# 13            Italian Restaurant                     Pharmacy
# 14                    Donut Shop                    Drugstore
# 15                Cosmetics Shop                  Pizza Place
# 17                      Dive Bar             Doner Restaurant
# 18                    Food Court            Convenience Store
# 19                    Donut Shop                    Drugstore
# 20                     Drugstore  Eastern European Restaurant
# 22                     Juice Bar         Fast Food Restaurant
# 23              Doner Restaurant                   Donut Shop
# 24                      Dive Bar                      Dog Run
# 25              Doner Restaurant                   Donut Shop
# 26                     Drugstore             Doner Restaurant
# 27                     Bike Shop               Discount Store
# 28                         Diner          Fried Chicken Joint
# 29                       Dog Run             Doner Restaurant
# 30                    Donut Shop                    Drugstore
# 31                      Dive Bar                      Dog Run
# 32                     Drugstore          Dumpling Restaurant
# 33                       Dog Run             Doner Restaurant
# 34                       Dog Run             Doner Restaurant
# 35                          Café                         Bank
# 36                Cosmetics Shop           Athletics & Sports
# 37   Eastern European Restaurant          Dumpling Restaurant
# 38                    Beer Store                    Bike Shop
# 39                   Coffee Shop                  Pizza Place
# 40                       Dog Run             Doner Restaurant
# 41               Bubble Tea Shop                   Restaurant
# 42                 Burrito Place                 Burger Joint
# 43             Convenience Store                      Brewery
# 44              Doner Restaurant                   Donut Shop
# 45                Breakfast Spot                Grocery Store
# 46            Mexican Restaurant                        Diner
# 47                          Park           Seafood Restaurant
# 48              Doner Restaurant                   Donut Shop
# 49                   Supermarket                  Pizza Place
# 50                       Dog Run             Doner Restaurant
# 51                          Café                       Market
# 52                           Gym                    Gastropub
# 53             Electronics Store        Performing Arts Venue
# 54          Fast Food Restaurant                   Restaurant
# 55                Cosmetics Shop               Clothing Store
# 56                    Steakhouse               Farmers Market
# 57                           Bar              Bubble Tea Shop
# 58           American Restaurant                          Gym
# 59                        Bakery          Sporting Goods Shop
# 60                        Bakery                Deli / Bodega
# 61                    Steakhouse                       Bakery
# 62                           Pub                   Restaurant
# 63              Doner Restaurant                   Donut Shop
# 64              Doner Restaurant                   Donut Shop
# 65                      Pharmacy                          Pub
# 66             French Restaurant               Sandwich Place
# 67                        Bakery        Vietnamese Restaurant
# 68               Harbor / Marina                 Airport Gate
# 69                  Cocktail Bar          Japanese Restaurant
# 70           American Restaurant             Asian Restaurant
# 71                   Coffee Shop                     Boutique
# 72                Discount Store                     Dive Bar
# 73                    Donut Shop                    Drugstore
# 74           Empanada Restaurant            Electronics Store
# 75            Italian Restaurant                        Diner
# 76          Gym / Fitness Center                      Brewery
# 77                   Men's Store                         Café
# 78          Caribbean Restaurant                 Climbing Gym
# 79                    Donut Shop                    Drugstore
# 80                       Dog Run             Doner Restaurant
# 81              Doner Restaurant                   Donut Shop
# 82                        Bakery    Cajun / Creole Restaurant
# 83                    Restaurant                Movie Theater
# 84                     Bookstore    Latin American Restaurant
# 85                           Spa         Fast Food Restaurant
# 86           American Restaurant    Middle Eastern Restaurant
# 87                    Skate Park                   Smoke Shop
# 88                   Pizza Place         Fast Food Restaurant
# 89                           Pub             Doner Restaurant
# 90                    Donut Shop          Dumpling Restaurant
# 91                    Donut Shop                    Drugstore
# 92                 Burrito Place                 Burger Joint
# 94                    Donut Shop                    Drugstore
# 95                      Pharmacy          Empanada Restaurant
# 96                    Donut Shop                    Drugstore
# 97                     Drugstore          Dumpling Restaurant
# 98                     Drugstore          Dumpling Restaurant
# 99                      Dive Bar                      Dog Run
# 100             Doner Restaurant                   Donut Shop
# 101                     Pharmacy            Electronics Store
# 102             Doner Restaurant                   Donut Shop
#
#           10th Most Common Venue
# 0              Electronics Store
# 1            Dumpling Restaurant
# 2                       Dive Bar
# 3                      Drugstore
# 4                    Curling Ice
# 5                      Drugstore
# 6                      Drugstore
# 7              German Restaurant
# 8                          Diner
# 9                      Drugstore
# 10                    Donut Shop
# 11             Electronics Store
# 12           Dumpling Restaurant
# 13   Eastern European Restaurant
# 14   Eastern European Restaurant
# 15                Sandwich Place
# 17                    Donut Shop
# 18                    Restaurant
# 19                   Yoga Studio
# 20                         Field
# 22           Japanese Restaurant
# 23                     Drugstore
# 24              Doner Restaurant
# 25                     Drugstore
# 26                    Donut Shop
# 27                    Restaurant
# 28            Frozen Yogurt Shop
# 29                    Donut Shop
# 30   Eastern European Restaurant
# 31              Doner Restaurant
# 32   Eastern European Restaurant
# 33                    Donut Shop
# 34                    Donut Shop
# 35          Gym / Fitness Center
# 36                  Dance Studio
# 37                     Drugstore
# 38             Fish & Chips Shop
# 39                Sandwich Place
# 40                    Donut Shop
# 41          Caribbean Restaurant
# 42                       Brewery
# 43            Seafood Restaurant
# 44           Dumpling Restaurant
# 45                           Gym
# 46                  Dessert Shop
# 47                    Restaurant
# 48                     Drugstore
# 49              Sushi Restaurant
# 50                    Donut Shop
# 51                Breakfast Spot
# 52                         Hotel
# 53                           Spa
# 54                         Diner
# 55                Breakfast Spot
# 56   Eastern European Restaurant
# 57                        Bakery
# 58                         Hotel
# 59                       Brewery
# 60           American Restaurant
# 61                           Gym
# 62                          Café
# 63           Dumpling Restaurant
# 64                     Drugstore
# 65                  Burger Joint
# 66                    Beer Store
# 67                   Gaming Cafe
# 68            Airport Food Court
# 69                Farmers Market
# 70                           Bar
# 71                 Women's Store
# 72                       Dog Run
# 73           Dumpling Restaurant
# 74                         Diner
# 75                     Nightclub
# 76     Middle Eastern Restaurant
# 77                    Restaurant
# 78                     Pet Store
# 79   Eastern European Restaurant
# 80                    Donut Shop
# 81                     Drugstore
# 82        Furniture / Home Store
# 83                       Dog Run
# 84             Fish & Chips Shop
# 85            Seafood Restaurant
# 86                     Drugstore
# 87                       Brewery
# 88                  Liquor Store
# 89                Discount Store
# 90            Dim Sum Restaurant
# 91           Dumpling Restaurant
# 92                   Social Club
# 94   Eastern European Restaurant
# 95          Ethiopian Restaurant
# 96             Electronics Store
# 97             Electronics Store
# 98             Electronics Store
# 99              Doner Restaurant
# 100          Dumpling Restaurant
# 101          Empanada Restaurant
# 102          Dumpling Restaurant

# %% [markdown]
# Now to visualise

# %%
#create map
toronto_latitude = 43.7001
toronto_longitude = -79.4163
map_clusters = folium.Map(location=[toronto_latitude,toronto_longitude],zoom_start=11)

#set colour scheme for clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0,1,len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#add markers
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster labels']):
    label = folium.Popup(str(poi) + 'Cluster' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %%
toronto_merged.loc[toronto_merged['Cluster labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster labels       1st Most Common Venue  \
# 2         Scarborough             0.0              Breakfast Spot
# 3         Scarborough             0.0                 Coffee Shop
# 4         Scarborough             0.0            Hakka Restaurant
# 5         Scarborough             0.0                  Playground
# 6         Scarborough             0.0            Department Store
# 7         Scarborough             0.0                    Bus Line
# 8         Scarborough             0.0         American Restaurant
# 9         Scarborough             0.0             College Stadium
# 10        Scarborough             0.0           Indian Restaurant
# 11        Scarborough             0.0              Breakfast Spot
# 12        Scarborough             0.0              Breakfast Spot
# 13        Scarborough             0.0                 Pizza Place
# 15        Scarborough             0.0        Fast Food Restaurant
# 17         North York             0.0        Fast Food Restaurant
# 18         North York             0.0              Clothing Store
# 19         North York             0.0         Japanese Restaurant
# 20         North York             0.0                   Cafeteria
# 22         North York             0.0                 Coffee Shop
# 24         North York             0.0                    Pharmacy
# 26         North York             0.0        Gym / Fitness Center
# 27         North York             0.0                         Gym
# 28         North York             0.0                 Coffee Shop
# 29         North York             0.0          Falafel Restaurant
# 31         North York             0.0               Grocery Store
# 32         North York             0.0                  Food Truck
# 33         North York             0.0              Discount Store
# 34         North York             0.0                Intersection
# 35          East York             0.0        Fast Food Restaurant
# 36          East York             0.0                  Beer Store
# 37       East Toronto             0.0        Other Great Outdoors
# 38          East York             0.0                 Coffee Shop
# 39          East York             0.0           Indian Restaurant
# 41       East Toronto             0.0            Greek Restaurant
# 42       East Toronto             0.0                        Park
# 43       East Toronto             0.0                        Café
# 45    Central Toronto             0.0        Gym / Fitness Center
# 46    Central Toronto             0.0                 Coffee Shop
# 47    Central Toronto             0.0                 Pizza Place
# 48    Central Toronto             0.0                       Trail
# 49    Central Toronto             0.0                 Coffee Shop
# 51   Downtown Toronto             0.0                 Coffee Shop
# 52   Downtown Toronto             0.0                 Coffee Shop
# 53   Downtown Toronto             0.0                 Coffee Shop
# 54   Downtown Toronto             0.0                 Coffee Shop
# 55   Downtown Toronto             0.0                 Coffee Shop
# 56   Downtown Toronto             0.0                 Coffee Shop
# 57   Downtown Toronto             0.0                 Coffee Shop
# 58   Downtown Toronto             0.0                 Coffee Shop
# 59   Downtown Toronto             0.0                 Coffee Shop
# 60   Downtown Toronto             0.0                 Coffee Shop
# 61   Downtown Toronto             0.0                 Coffee Shop
# 62         North York             0.0                 Coffee Shop
# 63    Central Toronto             0.0                      Garden
# 65    Central Toronto             0.0                 Coffee Shop
# 66   Downtown Toronto             0.0                        Café
# 67   Downtown Toronto             0.0                        Café
# 68   Downtown Toronto             0.0             Airport Service
# 69   Downtown Toronto             0.0                 Coffee Shop
# 70   Downtown Toronto             0.0                 Coffee Shop
# 71         North York             0.0      Furniture / Home Store
# 72         North York             0.0                        Park
# 73               York             0.0                       Trail
# 75   Downtown Toronto             0.0               Grocery Store
# 76       West Toronto             0.0                    Pharmacy
# 77       West Toronto             0.0                         Bar
# 78       West Toronto             0.0              Breakfast Spot
# 80               York             0.0              Sandwich Place
# 81               York             0.0                    Bus Line
# 82       West Toronto             0.0          Mexican Restaurant
# 83       West Toronto             0.0              Breakfast Spot
# 84       West Toronto             0.0                 Coffee Shop
# 85       Queen's Park             0.0                 Coffee Shop
# 86        Mississauga             0.0                 Coffee Shop
# 87       East Toronto             0.0        Gym / Fitness Center
# 88          Etobicoke             0.0                      Bakery
# 89          Etobicoke             0.0                 Pizza Place
# 91          Etobicoke             0.0                   Locksmith
# 92          Etobicoke             0.0              Hardware Store
# 94          Etobicoke             0.0                        Bank
# 95          Etobicoke             0.0                   Pet Store
# 96         North York             0.0         Empanada Restaurant
# 97         North York             0.0  Construction & Landscaping
# 99          Etobicoke             0.0                 Pizza Place
# 101         Etobicoke             0.0               Grocery Store
# 102         Etobicoke             0.0                         Bar
#
#              2nd Most Common Venue        3rd Most Common Venue  \
# 2              Rental Car Location                  Pizza Place
# 3                         Pharmacy            Korean Restaurant
# 4                  Thai Restaurant          Fried Chicken Joint
# 5                Convenience Store                  Yoga Studio
# 6                       Hobby Shop                  Coffee Shop
# 7             Fast Food Restaurant                 Intersection
# 8                            Motel               Farmers Market
# 9                             Café                 Skating Rink
# 10                       Pet Store        Vietnamese Restaurant
# 11                          Bakery                   Smoke Shop
# 12                          Lounge                 Skating Rink
# 13            Fast Food Restaurant                 Noodle House
# 15              Chinese Restaurant               Breakfast Spot
# 17                         Dog Run     Mediterranean Restaurant
# 18            Fast Food Restaurant                  Coffee Shop
# 19                            Bank                         Café
# 20                     Yoga Studio          Dumpling Restaurant
# 22                Ramen Restaurant                         Café
# 24                  Discount Store                Grocery Store
# 26            Caribbean Restaurant                         Café
# 27                Asian Restaurant                   Beer Store
# 28                   Deli / Bodega                  Pizza Place
# 29                  Massage Studio         Caribbean Restaurant
# 31                            Park                         Bank
# 32                  Baseball Field                 Home Service
# 33            Gym / Fitness Center                Grocery Store
# 34                     Coffee Shop                 Hockey Arena
# 35                     Pizza Place                    Pet Store
# 36                     Curling Ice                         Park
# 37               Health Food Store                          Pub
# 38             Sporting Goods Shop                 Burger Joint
# 39                    Burger Joint                  Yoga Studio
# 41                     Coffee Shop               Ice Cream Shop
# 42                  Ice Cream Shop                    Pet Store
# 43                     Coffee Shop                    Gastropub
# 45                            Park               Sandwich Place
# 46                  Clothing Store          Sporting Goods Shop
# 47                  Sandwich Place                 Dessert Shop
# 48                      Playground                  Summer Camp
# 49                             Pub          American Restaurant
# 51                      Restaurant                  Pizza Place
# 52             Japanese Restaurant             Sushi Restaurant
# 53                            Park                       Bakery
# 54                  Clothing Store               Cosmetics Shop
# 55                           Hotel           Italian Restaurant
# 56                    Cocktail Bar                         Café
# 57                            Café           Italian Restaurant
# 58                            Café                          Bar
# 59                           Hotel                     Aquarium
# 60                            Café                        Hotel
# 61                            Café                        Hotel
# 62              Italian Restaurant             Sushi Restaurant
# 63                     Music Venue                 Home Service
# 65                            Café               Sandwich Place
# 66                      Restaurant                    Bookstore
# 67   Vegetarian / Vegan Restaurant           Chinese Restaurant
# 68                Airport Terminal               Airport Lounge
# 69                            Café                   Restaurant
# 70                            Café                   Steakhouse
# 71                  Clothing Store            Accessories Store
# 72             Japanese Restaurant             Sushi Restaurant
# 73                           Field                      Dog Run
# 75                            Café                         Park
# 76                          Bakery                  Supermarket
# 77                     Coffee Shop             Asian Restaurant
# 78                            Café                  Coffee Shop
# 80                      Restaurant            Convenience Store
# 81            Caribbean Restaurant                  Pizza Place
# 82                             Bar                         Café
# 83                       Gift Shop  Eastern European Restaurant
# 84                            Café                  Pizza Place
# 85                           Diner                          Gym
# 86                           Hotel         Gym / Fitness Center
# 87                          Garden                   Comic Shop
# 88             American Restaurant                         Café
# 89                             Gym               Sandwich Place
# 91                  Baseball Field             Business Service
# 92                   Tanning Salon                Grocery Store
# 94                     Golf Course                  Yoga Studio
# 95                     Pizza Place                   Beer Store
# 96                    Home Service                  Yoga Studio
# 97                  Baseball Field                  Yoga Studio
# 99                    Intersection               Sandwich Place
# 101           Fast Food Restaurant                  Pizza Place
# 102            Rental Car Location                    Drugstore
#
#            4th Most Common Venue        5th Most Common Venue  \
# 2              Electronics Store               Medical Center
# 3                    Yoga Studio          Dumpling Restaurant
# 4                           Bank                       Bakery
# 5            Dumpling Restaurant               Discount Store
# 6             Chinese Restaurant                  Yoga Studio
# 7                  Metro Station                  Bus Station
# 8             Falafel Restaurant                  Event Space
# 9          General Entertainment                   Donut Shop
# 10     Latin American Restaurant           Chinese Restaurant
# 11     Middle Eastern Restaurant  Eastern European Restaurant
# 12                Clothing Store  Eastern European Restaurant
# 13           Fried Chicken Joint              Thai Restaurant
# 15             Indian Restaurant                Grocery Store
# 17                   Golf Course                         Pool
# 18                      Tea Room             Toy / Game Store
# 19            Chinese Restaurant                     Dive Bar
# 20                      Dive Bar                      Dog Run
# 22                   Pizza Place                   Restaurant
# 24                   Pizza Place                  Coffee Shop
# 26                Baseball Field             Basketball Court
# 27                   Coffee Shop         Fast Food Restaurant
# 28                    Restaurant             Sushi Restaurant
# 29                           Bar                  Coffee Shop
# 31                 Shopping Mall                        Hotel
# 32                   Yoga Studio                      Dog Run
# 33            Athletics & Sports                 Liquor Store
# 34         Portuguese Restaurant          Dumpling Restaurant
# 35            Athletics & Sports                    Gastropub
# 36                      Pharmacy                  Video Store
# 37                  Neighborhood                        Trail
# 38        Furniture / Home Store             Sushi Restaurant
# 39                          Bank                 Liquor Store
# 41            Italian Restaurant       Furniture / Home Store
# 42                   Pizza Place                Movie Theater
# 43            Italian Restaurant                       Bakery
# 45             Food & Drink Shop             Asian Restaurant
# 46                   Yoga Studio                   Bagel Shop
# 47                   Coffee Shop           Italian Restaurant
# 48                   Yoga Studio               Discount Store
# 49                    Restaurant                   Bagel Shop
# 51                           Pub           Italian Restaurant
# 52                       Gay Bar                   Restaurant
# 53                          Café           Mexican Restaurant
# 54     Middle Eastern Restaurant                         Café
# 55                          Café                   Restaurant
# 56                   Cheese Shop                       Bakery
# 57                Ice Cream Shop               Sandwich Place
# 58               Thai Restaurant                   Steakhouse
# 59            Italian Restaurant                         Café
# 60                    Restaurant           Italian Restaurant
# 61           American Restaurant                   Restaurant
# 62              Greek Restaurant               Ice Cream Shop
# 63                     Drugstore               Discount Store
# 65                   Pizza Place                         Park
# 66           Japanese Restaurant                          Bar
# 67                           Bar           Mexican Restaurant
# 68                 Boat or Ferry                     Boutique
# 69                      Beer Bar                        Hotel
# 70                         Hotel                   Restaurant
# 71           Arts & Crafts Store             Fraternity House
# 72                   Pizza Place                          Pub
# 73                  Hockey Arena                  Yoga Studio
# 75                   Coffee Shop                   Restaurant
# 76                Discount Store                          Bar
# 77                   Pizza Place                 Cocktail Bar
# 78                   Yoga Studio                          Bar
# 80         Check Cashing Service                  Yoga Studio
# 81             Convenience Store                  Yoga Studio
# 82                     Gastropub          Arts & Crafts Store
# 83                  Dessert Shop                          Bar
# 84            Italian Restaurant             Sushi Restaurant
# 85                          Park                Burrito Place
# 86           Fried Chicken Joint               Sandwich Place
# 87                          Park                  Pizza Place
# 88           Fried Chicken Joint               Sandwich Place
# 89                  Dance Studio                     Pharmacy
# 91                          Pool                  Yoga Studio
# 92          Fast Food Restaurant               Discount Store
# 94           Dumpling Restaurant                     Dive Bar
# 95                   Coffee Shop            Convenience Store
# 96           Dumpling Restaurant                     Dive Bar
# 97   Eastern European Restaurant                      Dog Run
# 99                   Coffee Shop           Chinese Restaurant
# 101               Sandwich Place                   Beer Store
# 102                  Yoga Studio                        Diner
#
#            6th Most Common Venue     7th Most Common Venue  \
# 2                   Intersection        Mexican Restaurant
# 3                       Dive Bar                   Dog Run
# 4           Caribbean Restaurant        Athletics & Sports
# 5                       Dive Bar                   Dog Run
# 6            Dumpling Restaurant                   Dog Run
# 7                   Soccer Field                    Bakery
# 8           Ethiopian Restaurant       Empanada Restaurant
# 9                 Discount Store                  Dive Bar
# 10                     Drugstore                  Dive Bar
# 11              Doner Restaurant                Donut Shop
# 12                       Dog Run          Doner Restaurant
# 13            Chinese Restaurant                      Bank
# 15               Bubble Tea Shop                  Pharmacy
# 17                   Yoga Studio       Dumpling Restaurant
# 18           Japanese Restaurant                    Bakery
# 19                       Dog Run          Doner Restaurant
# 20              Doner Restaurant                Donut Shop
# 22                Sandwich Place         Electronics Store
# 24                   Yoga Studio                 Drugstore
# 26           Japanese Restaurant               Yoga Studio
# 27                Sandwich Place       Sporting Goods Shop
# 28                          Bank               Bridal Shop
# 29                   Yoga Studio                 Drugstore
# 31                    Donut Shop            Discount Store
# 32              Doner Restaurant                Donut Shop
# 33           Dumpling Restaurant                  Dive Bar
# 34                Discount Store                  Dive Bar
# 35                  Intersection                  Pharmacy
# 36                  Skating Rink                  Bus Stop
# 37           Empanada Restaurant         Electronics Store
# 38                 Shopping Mall                Sports Bar
# 39                          Park                  Pharmacy
# 41                     Bookstore                   Brewery
# 42                           Pub            Sandwich Place
# 43           American Restaurant               Yoga Studio
# 45                         Hotel            Clothing Store
# 46                     Gift Shop             Metro Station
# 47                          Café          Sushi Restaurant
# 48                      Dive Bar                   Dog Run
# 49           Fried Chicken Joint                Sports Bar
# 51                   Flower Shop                    Bakery
# 52                   Men's Store  Mediterranean Restaurant
# 53                           Pub            Breakfast Spot
# 54                Ice Cream Shop                   Theater
# 55                  Cocktail Bar                  Beer Bar
# 56                      Beer Bar        Seafood Restaurant
# 57                  Burger Joint         Indian Restaurant
# 58                Breakfast Spot          Asian Restaurant
# 59                Scenic Lookout               Pizza Place
# 60                     Gastropub                       Bar
# 61                     Gastropub             Deli / Bodega
# 62                      Pharmacy               Pizza Place
# 63                      Dive Bar                   Dog Run
# 65                     BBQ Joint            Cosmetics Shop
# 66                        Bakery     College Arts Building
# 67                   Coffee Shop       Dumpling Restaurant
# 68              Sculpture Garden                       Bar
# 69          Fast Food Restaurant        Seafood Restaurant
# 70                 Deli / Bodega                       Gym
# 71                   Event Space        Miscellaneous Shop
# 72                   Yoga Studio          Doner Restaurant
# 73                      Dive Bar          Doner Restaurant
# 75                    Baby Store        Athletics & Sports
# 76                          Park                      Bank
# 77         Vietnamese Restaurant         French Restaurant
# 78                 Burrito Place                Restaurant
# 80                     Drugstore                  Dive Bar
# 81                      Dive Bar                   Dog Run
# 82                         Diner       Fried Chicken Joint
# 83                          Bank        Italian Restaurant
# 84                 Smoothie Shop                Restaurant
# 85            Italian Restaurant       Japanese Restaurant
# 86                 Burrito Place  Mediterranean Restaurant
# 87                    Restaurant             Burrito Place
# 88            Seafood Restaurant                Restaurant
# 89                   Coffee Shop              Skating Rink
# 91   Eastern European Restaurant          Doner Restaurant
# 92             Convenience Store            Sandwich Place
# 94                       Dog Run          Doner Restaurant
# 95                          Café              Liquor Store
# 96                       Dog Run          Doner Restaurant
# 97              Doner Restaurant                Donut Shop
# 99                    Donut Shop            Discount Store
# 101                  Coffee Shop       Fried Chicken Joint
# 102                     Dive Bar                   Dog Run
#
#            8th Most Common Venue        9th Most Common Venue  \
# 2                     Donut Shop               Discount Store
# 3               Doner Restaurant                   Donut Shop
# 4                         Lounge                 Cupcake Shop
# 5               Doner Restaurant                   Donut Shop
# 6               Doner Restaurant                   Donut Shop
# 7                           Park                    Gift Shop
# 8              Electronics Store  Eastern European Restaurant
# 9                        Dog Run             Doner Restaurant
# 10                       Dog Run             Doner Restaurant
# 11                     Drugstore          Dumpling Restaurant
# 12                    Donut Shop                    Drugstore
# 13            Italian Restaurant                     Pharmacy
# 15                Cosmetics Shop                  Pizza Place
# 17                      Dive Bar             Doner Restaurant
# 18                    Food Court            Convenience Store
# 19                    Donut Shop                    Drugstore
# 20                     Drugstore  Eastern European Restaurant
# 22                     Juice Bar         Fast Food Restaurant
# 24                      Dive Bar                      Dog Run
# 26                     Drugstore             Doner Restaurant
# 27                     Bike Shop               Discount Store
# 28                         Diner          Fried Chicken Joint
# 29                       Dog Run             Doner Restaurant
# 31                      Dive Bar                      Dog Run
# 32                     Drugstore          Dumpling Restaurant
# 33                       Dog Run             Doner Restaurant
# 34                       Dog Run             Doner Restaurant
# 35                          Café                         Bank
# 36                Cosmetics Shop           Athletics & Sports
# 37   Eastern European Restaurant          Dumpling Restaurant
# 38                    Beer Store                    Bike Shop
# 39                   Coffee Shop                  Pizza Place
# 41               Bubble Tea Shop                   Restaurant
# 42                 Burrito Place                 Burger Joint
# 43             Convenience Store                      Brewery
# 45                Breakfast Spot                Grocery Store
# 46            Mexican Restaurant                        Diner
# 47                          Park           Seafood Restaurant
# 48              Doner Restaurant                   Donut Shop
# 49                   Supermarket                  Pizza Place
# 51                          Café                       Market
# 52                           Gym                    Gastropub
# 53             Electronics Store        Performing Arts Venue
# 54          Fast Food Restaurant                   Restaurant
# 55                Cosmetics Shop               Clothing Store
# 56                    Steakhouse               Farmers Market
# 57                           Bar              Bubble Tea Shop
# 58           American Restaurant                          Gym
# 59                        Bakery          Sporting Goods Shop
# 60                        Bakery                Deli / Bodega
# 61                    Steakhouse                       Bakery
# 62                           Pub                   Restaurant
# 63              Doner Restaurant                   Donut Shop
# 65                      Pharmacy                          Pub
# 66             French Restaurant               Sandwich Place
# 67                        Bakery        Vietnamese Restaurant
# 68               Harbor / Marina                 Airport Gate
# 69                  Cocktail Bar          Japanese Restaurant
# 70           American Restaurant             Asian Restaurant
# 71                   Coffee Shop                     Boutique
# 72                Discount Store                     Dive Bar
# 73                    Donut Shop                    Drugstore
# 75            Italian Restaurant                        Diner
# 76          Gym / Fitness Center                      Brewery
# 77                   Men's Store                         Café
# 78          Caribbean Restaurant                 Climbing Gym
# 80                       Dog Run             Doner Restaurant
# 81              Doner Restaurant                   Donut Shop
# 82                        Bakery    Cajun / Creole Restaurant
# 83                    Restaurant                Movie Theater
# 84                     Bookstore    Latin American Restaurant
# 85                           Spa         Fast Food Restaurant
# 86           American Restaurant    Middle Eastern Restaurant
# 87                    Skate Park                   Smoke Shop
# 88                   Pizza Place         Fast Food Restaurant
# 89                           Pub             Doner Restaurant
# 91                    Donut Shop                    Drugstore
# 92                 Burrito Place                 Burger Joint
# 94                    Donut Shop                    Drugstore
# 95                      Pharmacy          Empanada Restaurant
# 96                    Donut Shop                    Drugstore
# 97                     Drugstore          Dumpling Restaurant
# 99                      Dive Bar                      Dog Run
# 101                     Pharmacy            Electronics Store
# 102             Doner Restaurant                   Donut Shop
#
#           10th Most Common Venue
# 2                       Dive Bar
# 3                      Drugstore
# 4                    Curling Ice
# 5                      Drugstore
# 6                      Drugstore
# 7              German Restaurant
# 8                          Diner
# 9                      Drugstore
# 10                    Donut Shop
# 11             Electronics Store
# 12           Dumpling Restaurant
# 13   Eastern European Restaurant
# 15                Sandwich Place
# 17                    Donut Shop
# 18                    Restaurant
# 19                   Yoga Studio
# 20                         Field
# 22           Japanese Restaurant
# 24              Doner Restaurant
# 26                    Donut Shop
# 27                    Restaurant
# 28            Frozen Yogurt Shop
# 29                    Donut Shop
# 31              Doner Restaurant
# 32   Eastern European Restaurant
# 33                    Donut Shop
# 34                    Donut Shop
# 35          Gym / Fitness Center
# 36                  Dance Studio
# 37                     Drugstore
# 38             Fish & Chips Shop
# 39                Sandwich Place
# 41          Caribbean Restaurant
# 42                       Brewery
# 43            Seafood Restaurant
# 45                           Gym
# 46                  Dessert Shop
# 47                    Restaurant
# 48                     Drugstore
# 49              Sushi Restaurant
# 51                Breakfast Spot
# 52                         Hotel
# 53                           Spa
# 54                         Diner
# 55                Breakfast Spot
# 56   Eastern European Restaurant
# 57                        Bakery
# 58                         Hotel
# 59                       Brewery
# 60           American Restaurant
# 61                           Gym
# 62                          Café
# 63           Dumpling Restaurant
# 65                  Burger Joint
# 66                    Beer Store
# 67                   Gaming Cafe
# 68            Airport Food Court
# 69                Farmers Market
# 70                           Bar
# 71                 Women's Store
# 72                       Dog Run
# 73           Dumpling Restaurant
# 75                     Nightclub
# 76     Middle Eastern Restaurant
# 77                    Restaurant
# 78                     Pet Store
# 80                    Donut Shop
# 81                     Drugstore
# 82        Furniture / Home Store
# 83                       Dog Run
# 84             Fish & Chips Shop
# 85            Seafood Restaurant
# 86                     Drugstore
# 87                       Brewery
# 88                  Liquor Store
# 89                Discount Store
# 91           Dumpling Restaurant
# 92                   Social Club
# 94   Eastern European Restaurant
# 95          Ethiopian Restaurant
# 96             Electronics Store
# 97             Electronics Store
# 99              Doner Restaurant
# 101          Empanada Restaurant
# 102          Dumpling Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 90  Etobicoke             1.0                  Park                 River
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 90             Drugstore        Discount Store              Dive Bar
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 90               Dog Run      Doner Restaurant            Donut Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 90   Dumpling Restaurant     Dim Sum Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  Scarborough             2.0  Fast Food Restaurant           Yoga Studio
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Eastern European Restaurant              Dive Bar               Dog Run
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Doner Restaurant            Donut Shop             Drugstore
#
#   9th Most Common Venue 10th Most Common Venue
# 0   Dumpling Restaurant      Electronics Store

# %%
toronto_merged.loc[toronto_merged['Cluster labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster labels 1st Most Common Venue  \
# 14        Scarborough             3.0                  Park
# 23         North York             3.0                  Park
# 25         North York             3.0  Fast Food Restaurant
# 30         North York             3.0                  Park
# 40          East York             3.0                  Park
# 44    Central Toronto             3.0                  Park
# 50   Downtown Toronto             3.0                  Park
# 64    Central Toronto             3.0                 Trail
# 74               York             3.0                  Park
# 79         North York             3.0                  Park
# 98               York             3.0                  Park
# 100         Etobicoke             3.0                  Park
#
#     2nd Most Common Venue        3rd Most Common Venue 4th Most Common Venue  \
# 14             Playground          Dumpling Restaurant        Discount Store
# 23                   Bank            Convenience Store           Flower Shop
# 25                   Park            Food & Drink Shop   Dumpling Restaurant
# 30                Airport                     Bus Stop   Dumpling Restaurant
# 40            Pizza Place                  Coffee Shop     Convenience Store
# 44     Photography Studio                  Swim School              Bus Line
# 50             Playground                     Building                 Trail
# 64                   Park             Sushi Restaurant         Jewelry Store
# 74          Women's Store                       Market  Fast Food Restaurant
# 79                 Bakery   Construction & Landscaping      Basketball Court
# 98            Yoga Studio  Eastern European Restaurant              Dive Bar
# 100           Pizza Place            Mobile Phone Shop             Drugstore
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 14               Dive Bar               Dog Run      Doner Restaurant
# 23            Yoga Studio   Dumpling Restaurant               Dog Run
# 25         Discount Store              Dive Bar               Dog Run
# 30               Dive Bar               Dog Run      Doner Restaurant
# 40    Dumpling Restaurant        Discount Store              Dive Bar
# 44              Drugstore              Dive Bar               Dog Run
# 50    Dumpling Restaurant        Discount Store              Dive Bar
# 64            Yoga Studio              Dive Bar               Dog Run
# 74     Falafel Restaurant           Event Space  Ethiopian Restaurant
# 79    Dumpling Restaurant               Dog Run      Doner Restaurant
# 98                Dog Run      Doner Restaurant            Donut Shop
# 100        Discount Store              Dive Bar               Dog Run
#
#     8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 14             Donut Shop             Drugstore  Eastern European Restaurant
# 23       Doner Restaurant            Donut Shop                    Drugstore
# 25       Doner Restaurant            Donut Shop                    Drugstore
# 30             Donut Shop             Drugstore  Eastern European Restaurant
# 40                Dog Run      Doner Restaurant                   Donut Shop
# 44       Doner Restaurant            Donut Shop          Dumpling Restaurant
# 50                Dog Run      Doner Restaurant                   Donut Shop
# 64       Doner Restaurant            Donut Shop                    Drugstore
# 74    Empanada Restaurant     Electronics Store                        Diner
# 79             Donut Shop             Drugstore  Eastern European Restaurant
# 98              Drugstore   Dumpling Restaurant            Electronics Store
# 100      Doner Restaurant            Donut Shop          Dumpling Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough             4.0         Moving Target                   Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1           Yoga Studio                 Diner              Dive Bar
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1               Dog Run      Doner Restaurant            Donut Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 1             Drugstore    Dumpling Restaurant
